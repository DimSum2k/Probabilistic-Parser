# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import io
import pickle as pkl
import time
import itertools
import string
#import multiprocessing as mp
#from multiprocessing import Pool
from collections import defaultdict
from nltk import Tree
from tqdm import tqdm
#import argparse

# %%
corpus_path="sequoia-corpus+fct.mrg_strict"
train_size=0.9
valid_size=0
test_size=0.1
embed_path='polyglot-fr.pkl'
lev_candidates=2
emb_candidates=20
use_damereau=False
linear_interpolation=0.2

# %%
def read_and_ignore_labels(corpus_path):
    corpus = []
    with io.open(corpus_path, encoding='utf-8') as f:
        for line in f:
            sentence = line.rstrip().split(" ")
            sentence = [word.split("-")[0] if word[0]=='(' else word for word in sentence]
            corpus.append(" ".join(sentence))
    return corpus

def extract_sentences(parse_corpus):
    return [" ".join(Tree.fromstring(sentence_parse).leaves()) for sentence_parse in parse_corpus]

corpus = read_and_ignore_labels(corpus_path)
sentences = extract_sentences(corpus)

# %%
def split_train_val_test(corpus, train_size=0.8, valid_size=0.1, test_size=0.1, random_state=1):
    
    corpus_size = len(corpus) 
    corpus_test = corpus[int(corpus_size*(train_size+valid_size)):]
    corpus_valid = corpus[int(corpus_size*train_size):int(corpus_size*(train_size+valid_size))]
    corpus_train = corpus[:int(np.ceil(corpus_size*train_size))]
    return corpus_train, corpus_valid, corpus_test

corpus_train, corpus_valid, corpus_test = split_train_val_test(corpus, 
                                                               train_size=train_size, 
                                                               valid_size=valid_size, 
                                                               test_size=test_size)

sentences_train = extract_sentences(corpus_train)
sentences_valid = extract_sentences(corpus_valid)
sentences_test = extract_sentences(corpus_test)
print(sentences_train[3])
print("Train corpus length : {} ({:.0f}%)".format(len(corpus_train),len(corpus_train)/len(corpus)*100))
print("Valid corpus length : {} ({:.0f}%)".format(len(corpus_valid),len(corpus_valid)/len(corpus)*100))
print("Test corpus length : {} (Last {:.0f}%)".format(len(corpus_test),len(corpus_test)/len(corpus)*100),"\n")
# Out:
# Ensuite , fut installée une autre forge à la Vacquerie , à l' emplacement aujourd'_hui de Cora .
# Train corpus length : 2790 (90%)
# Valid corpus length : 0 (0%)
# Test corpus length : 310 (Last 10%)

# %%
vocabulary = []
for sentence in sentences_train:
    vocabulary.extend(sentence.split())
    
vocabulary = np.unique(vocabulary)
vocabulary_indices = {word:idx for idx,word in enumerate(vocabulary)}
print("Vocabulary size :",len(vocabulary))
# Out:
# Vocabulary size : 9633

# %%
special_chars = ['½', 'ô', 'ù', 'ä', 'ß', 'î', 'ê', 'ï', 'è', 'á', '©', ' ', 'ó', 'ë', 'ö', 'à', 'â', 'û', '±', 'ç', 'é', '°', 'µ']
ascii_lowercase = [letter for letter in string.ascii_lowercase]
punctuations = [punctuation for punctuation in string.punctuation]
digits = [digit for digit in string.digits]
alphabet = ascii_lowercase+ascii_lowercase+punctuations+digits+special_chars

# %%
def damerau_levenshtein(w1, w2):
    
    w1, w2 = w1.lower(), w2.lower()
    n1, n2 = len(w1), len(w2)

    dict_alphabet_indices = {char:idx for idx,char in enumerate(alphabet)}
    
    da = np.zeros(len(alphabet), dtype=np.int8)
    d = np.zeros((n1+2, n2+2), dtype=np.int8)
    maxdist = n1 + n2
    d[0,0] = maxdist
    for i in range(n1+1):
        d[i+1,0] = maxdist
        d[i+1,1] = i
    for j in range(n2+1):
        d[0,j+1] = maxdist
        d[1,j+1] = j
        
    for i in range(1,n1+1):
        db = 0
        for j in range(1,n2+1):
            k = da[dict_alphabet_indices[w2[j-1]]]
            l = db
            if w1[i-1] == w2[j-1]:
                cost = 0
                db = j              
            else:
                cost = 1     
            d[i+1, j+1] = min(d[i,j]+cost, d[i+1,j]+1, d[i,j+1]+1, d[k,l]+(i-k-1)+1+(j-l-1))
            da[dict_alphabet_indices[w1[i-1]]] = i
            
    return d[-1,-1]

def levenshtein(w1, w2): 
    w1, w2 = w1.lower(), w2.lower()
    n1, n2 = len(w1), len(w2)
    lev_ = np.zeros((n1+1, n2+1))
    for i in range(n1+1):
        lev_[i,0] = i
    for j in range(n2+1):
        lev_[0,j] = j
    for i in range(1, n1+1):
        for j in range(1, n2+1):
            if w1[i-1] == w2[j-1]:
                lev_[i,j] = min(lev_[i-1,j]+1, lev_[i,j-1]+1, lev_[i-1,j-1])
                
            else:
                lev_[i,j] = min(lev_[i-1,j]+1, lev_[i,j-1]+1, lev_[i-1,j-1]+1)
    return lev_[n1, n2]

# %%
words, embeddings = pkl.load(open(embed_path, 'rb'), encoding = 'latin')
dict_words_embeddings = {word:embedding for word, embedding in zip(words, embeddings)}
# allow to extract multiple embeddings from the embeddingg dictionary
get_embedding = np.vectorize(lambda word : dict_words_embeddings.get(word,np.full(64, None)),signature="()->(n)")
vocabulary_ = np.array(list(set(vocabulary)&set(words)))
vocab_embeddings = np.vstack(get_embedding(vocabulary_))

# %%
del words, embeddings
print("Vocabulary size with available embeddings :",len(vocabulary_),"\n")
# Out:
# Vocabulary size with available embeddings : 7456

# %%
def find_closest_words_emb(word, k=5):
    
    if word in dict_words_embeddings:
        
        cosine_similarity = lambda x1,x2 : np.dot(x1,x2)/(np.linalg.norm(x1)*np.linalg.norm(x2))
        get_embedding = np.vectorize(lambda word : dict_words_embeddings.get(word,np.full(64, None)),signature="()->(n)")
        word_embedding = get_embedding(word)
        word_vocab_cosine = np.vectorize(lambda vocab_word_emb : cosine_similarity(vocab_word_emb,word_embedding), signature="(n)->()")
        vocab_similiraties = word_vocab_cosine(vocab_embeddings)
        return [word_emb_[1] for word_emb_ in sorted(zip(-vocab_similiraties,vocabulary_))[:k]]
    
    else:
        return []


def find_closest_words_lev(word, k=10, damereau=False):
    if damereau:
        levenstein = np.vectorize(lambda w : damerau_levenshtein(w,word))
    else:
        levenstein = np.vectorize(lambda w : levenshtein(w,word))
    vocab_distances = levenstein(vocabulary)
    return [word_lev_[1] for word_lev_ in sorted(zip(vocab_distances,vocabulary))[:k]]

# %%
class Bigrams_Unigrams():
    def __init__(self, vocabulary):
        self.vocabulary = list(vocabulary)
        self.vocab_dict = {word:idx for idx,word in enumerate(vocabulary)}
        self.n_grams = 2
        self.transition_matrix = np.ones((len(vocabulary),len(vocabulary)))
        self.unigram = np.zeros(len(vocabulary))    

    def learn(self, sentences):
        # Build bigram transition matrix and unigram probabilities
        tokens_list = [sentence.split() for sentence in sentences]
        for tokens in tokens_list:
            for i in range(len(tokens)):
                if i>=self.n_grams-1:
                    word = tokens[i]
                    grams = tokens[np.maximum(0,i-self.n_grams+1):i]
                    for previous_word in grams:
                        self.transition_matrix[self.vocab_dict[previous_word],self.vocab_dict[word]] += 1
                self.unigram[self.vocabulary.index(tokens[i])] += 1      
            
        self.transition_matrix = self.transition_matrix / np.sum(self.transition_matrix,axis=1).reshape(-1,1)
        self.unigram = self.unigram/np.sum(self.unigram)
        
        return self.unigram, self.transition_matrix

# %%
Bi_uni_grams = Bigrams_Unigrams(vocabulary=vocabulary)
unigrams, transition_matrix = Bi_uni_grams.learn(sentences_train)
inv = {v:k for (k,v) in Bi_uni_grams.vocab_dict.items()}
#inv[1000], unigrams[1000]
#np.argmax(transition_matrix[2980])
#transition_matrix[5254].sum()
#inv[5165], inv[2669]
#Bi_uni_grams.vocab_dict["forge"]
#Bi_uni_grams.vocab_dict["autre"]

# %%
def process_word(idx, word, score, proposed_sentence=None):
    if idx==0:    
        return np.log(unigrams[vocabulary_indices[word]])
    else:
        coeff = coeff = linear_interpolation
        return np.log((1-coeff)*transition_matrix[vocabulary_indices[proposed_sentence[-1]],vocabulary_indices[word]] + \
                      coeff*unigrams[vocabulary_indices[word]])

def propose_words(word, lev_candidates=10, emb_candidates=10, damereau=True):
    proposed_words,k = [], lev_candidates
    while not proposed_words:
        proposed_words = set(find_closest_words_emb(word, k=emb_candidates)).union(set(find_closest_words_lev(word, k=k, damereau=damereau)))
        k+=1
    return proposed_words

def OOV_module(sentence, lev_candidates=2, emb_candidates=20, vocabulary=vocabulary, damereau=False):

    score = 0
    proposed_sentence = []
    
    for idx,word in enumerate(sentence.split()):
        if word in vocabulary:
            score += process_word(idx,word,score,proposed_sentence)
            proposed_sentence = proposed_sentence + [word]
        else:
            proposed_words = propose_words(word, lev_candidates=lev_candidates, emb_candidates=emb_candidates, damereau=damereau)
            couples = []
            for proposed_word in proposed_words:
                couples.append((process_word(idx, proposed_word, score, proposed_sentence),proposed_word))

            best_score_word = sorted(couples)[-1]
            proposed_sentence = proposed_sentence + [best_score_word[1]]
            score += best_score_word[0]
    
    return " ".join(proposed_sentence)

# %%
def transform_parse(parse, to_chomsky=False):
    t = Tree.fromstring(parse)
    
    if to_chomsky:
        t.chomsky_normal_form(horzMarkov=2)
        t.collapse_unary(collapsePOS=True, collapseRoot=True)
    else:
        t.un_chomsky_normal_form()
    
    return " ".join(str(t).split())

# %%
def extract_lexicon(corpus):
    tokens_POS = []
    
    for sentence in corpus:
        tree = Tree.fromstring(sentence,remove_empty_top_bracketing=True)
        tree.chomsky_normal_form(horzMarkov=2)
        tree.collapse_unary(collapsePOS=True, collapseRoot=True)
        sentence_lexical_rules = [rule for rule in tree.productions() if rule.is_lexical()]
        tokens_POS.extend(sentence_lexical_rules)
    
    # Count pairs occurencies
    unique, counts = np.unique(tokens_POS, return_counts=True)  
    unique = np.array([[rule.lhs().symbol(), rule.rhs()[0].lower()] for rule in unique])
    counts = counts.astype(np.float64)
    
    # Compute probabilistic lexicon  
    data = np.hstack((unique,counts.reshape(-1,1)))
    
    lexicon_grammar = defaultdict(set)
    for key, val in data[:,:2]:
        lexicon_grammar[key].add(val)
    
    # Convert to matrix
    POS_tags, POS_tags_pos = np.unique(data[:, 0], return_inverse=True)
    words, words_pos = np.unique(data[:, 1], return_inverse=True)
    
    dict_POS_tags = {POS_tag:idx for idx,POS_tag in enumerate(POS_tags)}
    dict_words = {word:idx for idx,word in enumerate(words)}

    lexicon_probabilities = np.zeros((len(POS_tags), len(words)))
    lexicon_probabilities[POS_tags_pos, words_pos] = data[:, 2]
    
    lexicon_probabilities = lexicon_probabilities / np.sum(lexicon_probabilities,axis=1).reshape(-1,1)
    
    return lexicon_probabilities, dict_POS_tags, dict_words, lexicon_grammar

# %%
def extract_PCFG(corpus):
    tokens_POS = []
    axioms = set()
    for sentence in corpus:
        tree = Tree.fromstring(sentence, remove_empty_top_bracketing=True)
        tree.chomsky_normal_form(horzMarkov=2)
        tree.collapse_unary(collapsePOS=True, collapseRoot=True)
        rules = tree.productions()
        sentence_lexical_rules = [rule for rule in rules if rule.is_nonlexical()]
        axioms.add(rules[0].lhs().symbol())
        tokens_POS.extend(sentence_lexical_rules)
    
    # Count pairs occurencies
    unique, counts = np.unique(tokens_POS, return_counts=True)
    unique = np.array([[rule.lhs(), rule.rhs()]  for rule in unique])

    counts = counts.astype(np.float64)
    
    # Compute PCFG
    data = np.hstack((unique,counts.reshape(-1,1)))
    
    PCFG_grammar = defaultdict(set)
    for key, val in data[:,:2]:
        if len(val)>1: PCFG_grammar[key.symbol()].add((val[0].symbol(),val[1].symbol()))
        else: PCFG_grammar[key.symbol()].add(val[0].symbol())
    
    # Convert to matrix
    init_non_terminals, row_pos = np.unique(data[:, 0], return_inverse=True)
    target_non_terminals, col_pos = np.unique(data[:, 1], return_inverse=True)

    PCFG = np.zeros((len(init_non_terminals), len(target_non_terminals)))
    PCFG[row_pos, col_pos] = data[:, 2]
    
    PCFG = PCFG / np.sum(PCFG,axis=1).reshape(-1,1)
    
    dict_init_non_terminals = {NT.symbol():idx for idx,NT in enumerate(init_non_terminals)}
    dict_target_non_terminals = {(B.symbol(),C.symbol()):idx for idx,(B,C) in enumerate(target_non_terminals) if len((B,C))>1}
    dict_target_non_terminals.update({NT[0].symbol():idx for idx,NT in enumerate(target_non_terminals) if len(NT)==1})
    
    return PCFG, dict_init_non_terminals, dict_target_non_terminals, PCFG_grammar, list(axioms)

# %%
print("Extracting PCFG from the training corpus..","\n")
# lexicon_probabilities -> POS * words
# dict_POS_tags row index POS in lexicon_probabilities
# dict_words col index word in lexicon_probabilities
# lexicon_grammar is deterministic grammar
lexicon_probabilities, dict_POS_tags, dict_words, lexicon_grammar = extract_lexicon(corpus_train)

# PCFG -> Left POS * right POS
# dict_init_non_terminals row index Left POS in PCFG
# dict_target_non_terminals col index Right POS in PCFG
# PCFG_grammar is deterministic grammar
# axioms are the different types of root
PCFG, dict_init_non_terminals, dict_target_non_terminals, Grammar, axioms = extract_PCFG(corpus_train)
# Out:
# Extracting PCFG from the training corpus..

# %%
lexicon_probabilities.shape
# Out:
# (60, 8955)

# %%
lexicon_probabilities[:,0].sum()
# Out:
# 0.0031713997405218393

# %%
lexicon_probabilities[0,:].sum()
# Out:
# 1.0

# %%
dict_init_non_terminals
# Out:
# {'AP': 0,
#  'AP|<ADJ-AP>': 1,
#  'AP|<ADJ-COORD>': 2,
#  'AP|<ADJ-PONCT>': 3,
#  'AP|<ADJ-PP>': 4,
#  'AP|<ADJ-Ssub>': 5,
#  'AP|<ADJ-VPinf>': 6,
#  'AP|<ADV-ADJ>': 7,
#  'AP|<ADV-PONCT>': 8,
#  'AP|<ADV-PP>': 9,
#  'AP|<AP-PONCT>': 10,
#  'AP|<COORD-COORD>': 11,
#  'AP|<COORD-PONCT>': 12,
#  'AP|<COORD-PP>': 13,
#  'AP|<NP-PONCT>': 14,
#  'AP|<PONCT-ADJ>': 15,
#  'AP|<PONCT-ADV>': 16,
#  'AP|<PONCT-AP>': 17,
#  'AP|<PONCT-COORD>': 18,
#  'AP|<PONCT-NP>': 19,
#  'AP|<PONCT-PP>': 20,
#  'AP|<PONCT-Ssub>': 21,
#  'AP|<PONCT-VPinf>': 22,
#  'AP|<PONCT-VPpart>': 23,
#  'AP|<PP-COORD>': 24,
#  'AP|<PP-PONCT>': 25,
#  'AP|<PP-PP>': 26,
#  'AP|<PP-Ssub>': 27,
#  'AP|<PP-VPinf>': 28,
#  'AP|<Ssub-VPinf>': 29,
#  'AP|<VPpart-PONCT>': 30,
#  'AdP': 31,
#  'AdP|<ADV-ADV>': 32,
#  'AdP|<ADV-AP>': 33,
#  'AdP|<ADV-PONCT>': 34,
#  'AdP|<ADV-PP>': 35,
#  'AdP|<ADV-Ssub>': 36,
#  'AdP|<DET-ADV>': 37,
#  'AdP|<PONCT-ADV>': 38,
#  'AdP|<PONCT-PP>': 39,
#  'AdP|<PONCT-Srel>': 40,
#  'AdP|<PP-PONCT>': 41,
#  'COORD': 42,
#  'COORD+NP': 43,
#  'COORD+VPpart': 44,
#  'COORD|<ADV-ADV>': 45,
#  'COORD|<ADV-AP>': 46,
#  'COORD|<ADV-NP>': 47,
#  'COORD|<ADV-PONCT>': 48,
#  'COORD|<ADV-PP>': 49,
#  'COORD|<ADV-Ssub>': 50,
#  'COORD|<ADV-VPinf>': 51,
#  'COORD|<ADV-VPpart>': 52,
#  'COORD|<AP-ADV>': 53,
#  'COORD|<AP-PONCT>': 54,
#  'COORD|<AP-PP>': 55,
#  'COORD|<AP-Ssub>': 56,
#  'COORD|<AP-VPinf>': 57,
#  'COORD|<AdP-NP>': 58,
#  'COORD|<AdP-PONCT>': 59,
#  'COORD|<CC-AP>': 60,
#  'COORD|<CC-PONCT>': 61,
#  'COORD|<CC-Srel>': 62,
#  'COORD|<CC-Ssub>': 63,
#  'COORD|<NP-NP>': 64,
#  'COORD|<NP-PONCT>': 65,
#  'COORD|<NP-PP>': 66,
#  'COORD|<NP-Sint>': 67,
#  'COORD|<NP-VN>': 68,
#  'COORD|<NP-VPinf>': 69,
#  'COORD|<NP-VPpart>': 70,
#  'COORD|<PONCT-ADV>': 71,
#  'COORD|<PONCT-AP>': 72,
#  'COORD|<PONCT-COORD>': 73,
#  'COORD|<PONCT-NP>': 74,
#  'COORD|<PONCT-PP>': 75,
#  'COORD|<PONCT-Sint>': 76,
#  'COORD|<PONCT-Ssub>': 77,
#  'COORD|<PONCT-VN>': 78,
#  'COORD|<PONCT-VPinf>': 79,
#  'COORD|<PONCT-VPpart>': 80,
#  'COORD|<PP-COORD>': 81,
#  'COORD|<PP-NP>': 82,
#  'COORD|<PP-PONCT>': 83,
#  'COORD|<PP-PP>': 84,
#  'COORD|<PP-VPinf>': 85,
#  'COORD|<Sint-PONCT>': 86,
#  'COORD|<Sint-VPinf>': 87,
#  'COORD|<Ssub-PONCT>': 88,
#  'COORD|<VN-ADV>': 89,
#  'COORD|<VN-AP>': 90,
#  'COORD|<VN-AdP>': 91,
#  'COORD|<VN-NP>': 92,
#  'COORD|<VN-PONCT>': 93,
#  'COORD|<VN-PP>': 94,
#  'COORD|<VN-Ssub>': 95,
#  'COORD|<VN-VPinf>': 96,
#  'COORD|<VN-VPpart>': 97,
#  'COORD|<VPP-PP>': 98,
#  'COORD|<VPinf-PONCT>': 99,
#  'COORD|<VPinf-PP>': 100,
#  'COORD|<VPpart-ADV>': 101,
#  'COORD|<VPpart-COORD>': 102,
#  'COORD|<VPpart-NP>': 103,
#  'NP': 104,
#  'NP+NP': 105,
#  'NP|<ADJ-ADJ>': 106,
#  'NP|<ADJ-COORD>': 107,
#  'NP|<ADJ-NC>': 108,
#  'NP|<ADJ-NPP>': 109,
#  'NP|<ADJ-P>': 110,
#  'NP|<ADJ-PONCT>': 111,
#  'NP|<ADJ-PP>': 112,
#  'NP|<ADJ-Srel>': 113,
#  'NP|<ADJ-VPinf>': 114,
#  'NP|<ADJ-VPpart>': 115,
#  'NP|<ADV-ADJ>': 116,
#  'NP|<ADV-AP>': 117,
#  'NP|<ADV-NC>': 118,
#  'NP|<ADV-NP>': 119,
#  'NP|<ADV-P>': 120,
#  'NP|<ADV-PONCT>': 121,
#  'NP|<ADV-PP>': 122,
#  'NP|<ADV-Ssub>': 123,
#  'NP|<ADV-VPinf>': 124,
#  'NP|<AP-ADV>': 125,
#  'NP|<AP-AP>': 126,
#  'NP|<AP-COORD>': 127,
#  'NP|<AP-NC>': 128,
#  'NP|<AP-NP>': 129,
#  'NP|<AP-NPP>': 130,
#  'NP|<AP-PONCT>': 131,
#  'NP|<AP-PP>': 132,
#  'NP|<AP-Srel>': 133,
#  'NP|<AP-Ssub>': 134,
#  'NP|<AP-VPinf>': 135,
#  'NP|<AP-VPpart>': 136,
#  'NP|<AdP-VPpart>': 137,
#  'NP|<CC-DET>': 138,
#  'NP|<COORD-AP>': 139,
#  'NP|<COORD-COORD>': 140,
#  'NP|<COORD-NC>': 141,
#  'NP|<COORD-NPP>': 142,
#  'NP|<COORD-PONCT>': 143,
#  'NP|<COORD-PP>': 144,
#  'NP|<COORD-Srel>': 145,
#  'NP|<COORD-Ssub>': 146,
#  'NP|<COORD-VPpart>': 147,
#  'NP|<DET-ADJ>': 148,
#  'NP|<DET-CC>': 149,
#  'NP|<DET-DET>': 150,
#  'NP|<DET-NC>': 151,
#  'NP|<DET-NPP>': 152,
#  'NP|<DET-P>': 153,
#  'NP|<DET-PONCT>': 154,
#  'NP|<DET-PP>': 155,
#  'NP|<DET-PRO>': 156,
#  'NP|<ET-COORD>': 157,
#  'NP|<ET-ET>': 158,
#  'NP|<ET-NPP>': 159,
#  'NP|<ET-PONCT>': 160,
#  'NP|<NC-ADJ>': 161,
#  'NP|<NC-ADV>': 162,
#  'NP|<NC-AP>': 163,
#  'NP|<NC-AdP>': 164,
#  'NP|<NC-COORD>': 165,
#  'NP|<NC-DET>': 166,
#  'NP|<NC-ET>': 167,
#  'NP|<NC-NC>': 168,
#  'NP|<NC-NP>': 169,
#  'NP|<NC-NPP>': 170,
#  'NP|<NC-PONCT>': 171,
#  'NP|<NC-PP>': 172,
#  'NP|<NC-Srel>': 173,
#  'NP|<NC-Ssub>': 174,
#  'NP|<NC-VPinf>': 175,
#  'NP|<NC-VPpart>': 176,
#  'NP|<NP-COORD>': 177,
#  'NP|<NP-NP>': 178,
#  'NP|<NP-NPP>': 179,
#  'NP|<NP-PONCT>': 180,
#  'NP|<NP-PP>': 181,
#  'NP|<NP-Srel>': 182,
#  'NP|<NP-Ssub>': 183,
#  'NP|<NP-VPpart>': 184,
#  'NP|<NPP-AP>': 185,
#  'NP|<NPP-COORD>': 186,
#  'NP|<NPP-DET>': 187,
#  'NP|<NPP-ET>': 188,
#  'NP|<NPP-NC>': 189,
#  'NP|<NPP-NPP>': 190,
#  'NP|<NPP-PONCT>': 191,
#  'NP|<NPP-PP>': 192,
#  'NP|<NPP-Srel>': 193,
#  'NP|<NPP-VPpart>': 194,
#  'NP|<P-ADJ>': 195,
#  'NP|<P-DET>': 196,
#  'NP|<P-NC>': 197,
#  'NP|<P-NP>': 198,
#  'NP|<P-PRO>': 199,
#  'NP|<PONCT-ADJ>': 200,
#  'NP|<PONCT-ADV>': 201,
#  'NP|<PONCT-AP>': 202,
#  'NP|<PONCT-COORD>': 203,
#  'NP|<PONCT-DET>': 204,
#  'NP|<PONCT-ET>': 205,
#  'NP|<PONCT-NC>': 206,
#  'NP|<PONCT-NP>': 207,
#  'NP|<PONCT-NPP>': 208,
#  'NP|<PONCT-PONCT>': 209,
#  'NP|<PONCT-PP>': 210,
#  'NP|<PONCT-Sint>': 211,
#  'NP|<PONCT-Srel>': 212,
#  'NP|<PONCT-Ssub>': 213,
#  'NP|<PONCT-VPinf>': 214,
#  'NP|<PONCT-VPpart>': 215,
#  'NP|<PP-ADV>': 216,
#  'NP|<PP-AP>': 217,
#  'NP|<PP-AdP>': 218,
#  'NP|<PP-COORD>': 219,
#  'NP|<PP-ET>': 220,
#  'NP|<PP-NC>': 221,
#  'NP|<PP-NP>': 222,
#  'NP|<PP-NPP>': 223,
#  'NP|<PP-PONCT>': 224,
#  'NP|<PP-PP>': 225,
#  'NP|<PP-Srel>': 226,
#  'NP|<PP-Ssub>': 227,
#  'NP|<PP-VPinf>': 228,
#  'NP|<PP-VPpart>': 229,
#  'NP|<PREF-ADJ>': 230,
#  'NP|<PREF-NC>': 231,
#  'NP|<PRO-COORD>': 232,
#  'NP|<PRO-PONCT>': 233,
#  'NP|<PRO-PP>': 234,
#  'NP|<PRO-Srel>': 235,
#  'NP|<PRO-VPpart>': 236,
#  'NP|<Sint-PONCT>': 237,
#  'NP|<Srel-COORD>': 238,
#  'NP|<Srel-PONCT>': 239,
#  'NP|<Srel-PP>': 240,
#  'NP|<Srel-VPpart>': 241,
#  'NP|<Ssub-COORD>': 242,
#  'NP|<Ssub-PONCT>': 243,
#  'NP|<VN-NP>': 244,
#  'NP|<VPinf-PONCT>': 245,
#  'NP|<VPinf-PP>': 246,
#  'NP|<VPinf-Srel>': 247,
#  'NP|<VPpart-AP>': 248,
#  'NP|<VPpart-COORD>': 249,
#  'NP|<VPpart-NC>': 250,
#  'NP|<VPpart-PONCT>': 251,
#  'NP|<VPpart-PP>': 252,
#  'NP|<VPpart-Srel>': 253,
#  'NP|<VPpart-Ssub>': 254,
#  'NP|<VPpart-VPinf>': 255,
#  'NP|<VPpart-VPpart>': 256,
#  'PP': 257,
#  'PP+AdP': 258,
#  'PP|<ADV-NP>': 259,
#  'PP|<ADV-P+D>': 260,
#  'PP|<ADV-PONCT>': 261,
#  'PP|<AP-PONCT>': 262,
#  'PP|<COORD-COORD>': 263,
#  'PP|<COORD-NP>': 264,
#  'PP|<COORD-PONCT>': 265,
#  'PP|<COORD-Ssub>': 266,
#  'PP|<NC-PP>': 267,
#  'PP|<NP-ADV>': 268,
#  'PP|<NP-COORD>': 269,
#  'PP|<NP-NP>': 270,
#  'PP|<NP-PONCT>': 271,
#  'PP|<NP-PP>': 272,
#  'PP|<NP-Ssub>': 273,
#  'PP|<NP-VPpart>': 274,
#  'PP|<P+D-NP>': 275,
#  'PP|<P-NP>': 276,
#  'PP|<P-VPpart>': 277,
#  'PP|<PONCT-ADV>': 278,
#  'PP|<PONCT-AP>': 279,
#  'PP|<PONCT-COORD>': 280,
#  'PP|<PONCT-NP>': 281,
#  'PP|<PONCT-PONCT>': 282,
#  'PP|<PONCT-PP>': 283,
#  'PP|<PONCT-Sint>': 284,
#  'PP|<PONCT-Srel>': 285,
#  'PP|<PONCT-VPinf>': 286,
#  'PP|<PP-NP>': 287,
#  'PP|<PP-PONCT>': 288,
#  'PP|<PP-PP>': 289,
#  'PP|<PP-VPinf>': 290,
#  'PP|<Sint-PONCT>': 291,
#  'PP|<VPpart-COORD>': 292,
#  'SENT': 293,
#  'SENT+AP': 294,
#  'SENT+COORD': 295,
#  'SENT+NP': 296,
#  'SENT+PP': 297,
#  'SENT+VPinf': 298,
#  'SENT|<ADV-ADV>': 299,
#  'SENT|<ADV-AP>': 300,
#  'SENT|<ADV-AdP>': 301,
#  'SENT|<ADV-COORD>': 302,
#  'SENT|<ADV-NP>': 303,
#  'SENT|<ADV-PONCT>': 304,
#  'SENT|<ADV-PP>': 305,
#  'SENT|<ADV-Ssub>': 306,
#  'SENT|<ADV-VN>': 307,
#  'SENT|<ADV-VPinf>': 308,
#  'SENT|<ADV-VPpart>': 309,
#  'SENT|<AP-ADV>': 310,
#  'SENT|<AP-COORD>': 311,
#  'SENT|<AP-NP>': 312,
#  'SENT|<AP-PONCT>': 313,
#  'SENT|<AP-PP>': 314,
#  'SENT|<AP-Ssub>': 315,
#  'SENT|<AP-VPinf>': 316,
#  'SENT|<AdP-NP>': 317,
#  'SENT|<AdP-PONCT>': 318,
#  'SENT|<AdP-PP>': 319,
#  'SENT|<AdP-Ssub>': 320,
#  'SENT|<AdP-VPinf>': 321,
#  'SENT|<COORD-COORD>': 322,
#  'SENT|<COORD-NP>': 323,
#  'SENT|<COORD-PONCT>': 324,
#  'SENT|<COORD-PP>': 325,
#  'SENT|<COORD-Ssub>': 326,
#  'SENT|<NP-ADV>': 327,
#  'SENT|<NP-AP>': 328,
#  'SENT|<NP-COORD>': 329,
#  'SENT|<NP-NC>': 330,
#  'SENT|<NP-NP>': 331,
#  'SENT|<NP-PONCT>': 332,
#  'SENT|<NP-PP>': 333,
#  'SENT|<NP-Sint>': 334,
#  'SENT|<NP-Srel>': 335,
#  'SENT|<NP-Ssub>': 336,
#  'SENT|<NP-VN>': 337,
#  'SENT|<NP-VPinf>': 338,
#  'SENT|<NP-VPpart>': 339,
#  'SENT|<NPP-PONCT>': 340,
#  'SENT|<PONCT-ADV>': 341,
#  'SENT|<PONCT-AP>': 342,
#  'SENT|<PONCT-AdP>': 343,
#  'SENT|<PONCT-COORD>': 344,
#  'SENT|<PONCT-NP>': 345,
#  'SENT|<PONCT-NPP>': 346,
#  'SENT|<PONCT-PONCT>': 347,
#  'SENT|<PONCT-PP>': 348,
#  'SENT|<PONCT-Sint>': 349,
#  'SENT|<PONCT-Srel>': 350,
#  'SENT|<PONCT-Ssub>': 351,
#  'SENT|<PONCT-VN>': 352,
#  'SENT|<PONCT-VPinf>': 353,
#  'SENT|<PONCT-VPpart>': 354,
#  'SENT|<PP-ADV>': 355,
#  'SENT|<PP-AP>': 356,
#  'SENT|<PP-AdP>': 357,
#  'SENT|<PP-COORD>': 358,
#  'SENT|<PP-NP>': 359,
#  'SENT|<PP-PONCT>': 360,
#  'SENT|<PP-PP>': 361,
#  'SENT|<PP-Srel>': 362,
#  'SENT|<PP-Ssub>': 363,
#  'SENT|<PP-VN>': 364,
#  'SENT|<PP-VPinf>': 365,
#  'SENT|<PP-VPpart>': 366,
#  'SENT|<Sint-PONCT>': 367,
#  'SENT|<Sint-Sint>': 368,
#  'SENT|<Sint-VN>': 369,
#  'SENT|<Srel-PONCT>': 370,
#  'SENT|<Ssub-COORD>': 371,
#  'SENT|<Ssub-NP>': 372,
#  'SENT|<Ssub-PONCT>': 373,
#  'SENT|<Ssub-VN>': 374,
#  'SENT|<Ssub-VPpart>': 375,
#  'SENT|<VN-ADV>': 376,
#  'SENT|<VN-AP>': 377,
#  'SENT|<VN-AdP>': 378,
#  'SENT|<VN-COORD>': 379,
#  'SENT|<VN-NP>': 380,
#  'SENT|<VN-PONCT>': 381,
#  'SENT|<VN-PP>': 382,
#  'SENT|<VN-Srel>': 383,
#  'SENT|<VN-Ssub>': 384,
#  'SENT|<VN-VPinf>': 385,
#  'SENT|<VN-VPpart>': 386,
#  'SENT|<VPinf-ADV>': 387,
#  'SENT|<VPinf-COORD>': 388,
#  'SENT|<VPinf-PONCT>': 389,
#  'SENT|<VPinf-PP>': 390,
#  'SENT|<VPinf-Sint>': 391,
#  'SENT|<VPinf-Ssub>': 392,
#  'SENT|<VPinf-VPinf>': 393,
#  'SENT|<VPinf-VPpart>': 394,
#  'SENT|<VPpart-PONCT>': 395,
#  'SENT|<VPpart-PP>': 396,
#  'SENT|<VPpart-Ssub>': 397,
#  'Sint': 398,
#  'Sint+VN': 399,
#  'Sint+VPinf': 400,
#  'Sint|<ADV-ADV>': 401,
#  'Sint|<ADV-AP>': 402,
#  'Sint|<ADV-AdP>': 403,
#  'Sint|<ADV-COORD>': 404,
#  'Sint|<ADV-NP>': 405,
#  'Sint|<ADV-PONCT>': 406,
#  'Sint|<ADV-PP>': 407,
#  'Sint|<ADV-Ssub>': 408,
#  'Sint|<ADV-VN>': 409,
#  'Sint|<ADV-VPinf>': 410,
#  'Sint|<AP-COORD>': 411,
#  'Sint|<AP-NP>': 412,
#  'Sint|<AP-PONCT>': 413,
#  'Sint|<AP-PP>': 414,
#  'Sint|<AP-Ssub>': 415,
#  'Sint|<AP-VPinf>': 416,
#  'Sint|<AdP-NP>': 417,
#  'Sint|<AdP-PONCT>': 418,
#  'Sint|<AdP-Ssub>': 419,
#  'Sint|<COORD-COORD>': 420,
#  'Sint|<COORD-PONCT>': 421,
#  'Sint|<COORD-Ssub>': 422,
#  'Sint|<I-Sint>': 423,
#  'Sint|<NP-COORD>': 424,
#  'Sint|<NP-PONCT>': 425,
#  'Sint|<NP-PP>': 426,
#  'Sint|<NP-Srel>': 427,
#  'Sint|<NP-Ssub>': 428,
#  'Sint|<NP-VN>': 429,
#  'Sint|<NP-VPinf>': 430,
#  'Sint|<PONCT-ADV>': 431,
#  'Sint|<PONCT-AP>': 432,
#  'Sint|<PONCT-COORD>': 433,
#  'Sint|<PONCT-I>': 434,
#  'Sint|<PONCT-NP>': 435,
#  'Sint|<PONCT-PP>': 436,
#  'Sint|<PONCT-Ssub>': 437,
#  'Sint|<PONCT-VN>': 438,
#  'Sint|<PONCT-VPinf>': 439,
#  'Sint|<PONCT-VPpart>': 440,
#  'Sint|<PP-COORD>': 441,
#  'Sint|<PP-NP>': 442,
#  'Sint|<PP-PONCT>': 443,
#  'Sint|<PP-PP>': 444,
#  'Sint|<PP-Srel>': 445,
#  'Sint|<PP-Ssub>': 446,
#  'Sint|<PP-VPinf>': 447,
#  'Sint|<Ssub-PONCT>': 448,
#  'Sint|<VN-ADV>': 449,
#  'Sint|<VN-AP>': 450,
#  'Sint|<VN-AdP>': 451,
#  'Sint|<VN-COORD>': 452,
#  'Sint|<VN-NP>': 453,
#  'Sint|<VN-PONCT>': 454,
#  'Sint|<VN-PP>': 455,
#  'Sint|<VN-Ssub>': 456,
#  'Sint|<VN-VPinf>': 457,
#  'Sint|<VPinf-COORD>': 458,
#  'Sint|<VPinf-PONCT>': 459,
#  'Sint|<VPinf-Ssub>': 460,
#  'Srel': 461,
#  'Srel|<ADV-AP>': 462,
#  'Srel|<ADV-AdP>': 463,
#  'Srel|<ADV-NP>': 464,
#  'Srel|<ADV-PONCT>': 465,
#  'Srel|<ADV-PP>': 466,
#  'Srel|<ADV-Ssub>': 467,
#  'Srel|<ADV-VN>': 468,
#  'Srel|<ADV-VPinf>': 469,
#  'Srel|<AP-ADV>': 470,
#  'Srel|<AP-COORD>': 471,
#  'Srel|<AP-NP>': 472,
#  'Srel|<AP-PP>': 473,
#  'Srel|<AP-VPinf>': 474,
#  'Srel|<AdP-COORD>': 475,
#  'Srel|<AdP-PONCT>': 476,
#  'Srel|<COORD-COORD>': 477,
#  'Srel|<COORD-PONCT>': 478,
#  'Srel|<COORD-PP>': 479,
#  'Srel|<NP-ADV>': 480,
#  'Srel|<NP-COORD>': 481,
#  'Srel|<NP-NP>': 482,
#  'Srel|<NP-PONCT>': 483,
#  'Srel|<NP-PP>': 484,
#  'Srel|<NP-Ssub>': 485,
#  'Srel|<NP-VN>': 486,
#  'Srel|<NP-VPinf>': 487,
#  'Srel|<PONCT-ADV>': 488,
#  'Srel|<PONCT-AP>': 489,
#  'Srel|<PONCT-AdP>': 490,
#  'Srel|<PONCT-COORD>': 491,
#  'Srel|<PONCT-NP>': 492,
#  'Srel|<PONCT-PP>': 493,
#  'Srel|<PONCT-Ssub>': 494,
#  'Srel|<PONCT-VN>': 495,
#  'Srel|<PONCT-VPinf>': 496,
#  'Srel|<PONCT-VPpart>': 497,
#  'Srel|<PP-COORD>': 498,
#  'Srel|<PP-NP>': 499,
#  'Srel|<PP-PONCT>': 500,
#  'Srel|<PP-PP>': 501,
#  'Srel|<PP-Ssub>': 502,
#  'Srel|<PP-VN>': 503,
#  'Srel|<PP-VPinf>': 504,
#  'Srel|<Ssub-COORD>': 505,
#  'Srel|<Ssub-PONCT>': 506,
#  'Srel|<VN-ADV>': 507,
#  'Srel|<VN-AP>': 508,
#  'Srel|<VN-AdP>': 509,
#  'Srel|<VN-COORD>': 510,
#  'Srel|<VN-NP>': 511,
#  'Srel|<VN-PONCT>': 512,
#  'Srel|<VN-PP>': 513,
#  'Srel|<VN-Ssub>': 514,
#  'Srel|<VN-VPinf>': 515,
#  'Srel|<VN-VPpart>': 516,
#  'Srel|<VPinf-COORD>': 517,
#  'Srel|<VPinf-NP>': 518,
#  'Srel|<VPinf-PONCT>': 519,
#  'Srel|<VPinf-Ssub>': 520,
#  'Srel|<VPinf-VN>': 521,
#  'Srel|<VPpart-PONCT>': 522,
#  'Ssub': 523,
#  'Ssub|<ADV-ADV>': 524,
#  'Ssub|<ADV-AP>': 525,
#  'Ssub|<ADV-NP>': 526,
#  'Ssub|<ADV-PONCT>': 527,
#  'Ssub|<ADV-PP>': 528,
#  'Ssub|<ADV-Ssub>': 529,
#  'Ssub|<ADV-VN>': 530,
#  'Ssub|<ADV-VPinf>': 531,
#  'Ssub|<AP-ADV>': 532,
#  'Ssub|<AP-COORD>': 533,
#  'Ssub|<AP-NP>': 534,
#  'Ssub|<AP-PONCT>': 535,
#  'Ssub|<AP-PP>': 536,
#  'Ssub|<AP-Ssub>': 537,
#  'Ssub|<AP-VN>': 538,
#  'Ssub|<AP-VPinf>': 539,
#  'Ssub|<AdP-AP>': 540,
#  'Ssub|<AdP-NP>': 541,
#  'Ssub|<AdP-PP>': 542,
#  'Ssub|<COORD-AP>': 543,
#  'Ssub|<COORD-COORD>': 544,
#  'Ssub|<COORD-NP>': 545,
#  'Ssub|<COORD-PONCT>': 546,
#  'Ssub|<CS-NP>': 547,
#  'Ssub|<CS-VN>': 548,
#  'Ssub|<NP-ADV>': 549,
#  'Ssub|<NP-AdP>': 550,
#  'Ssub|<NP-COORD>': 551,
#  'Ssub|<NP-NP>': 552,
#  'Ssub|<NP-PONCT>': 553,
#  'Ssub|<NP-PP>': 554,
#  'Ssub|<NP-Srel>': 555,
#  'Ssub|<NP-Ssub>': 556,
#  'Ssub|<NP-VN>': 557,
#  'Ssub|<NP-VPinf>': 558,
#  'Ssub|<NP-VPpart>': 559,
#  'Ssub|<PONCT-ADV>': 560,
#  'Ssub|<PONCT-AP>': 561,
#  'Ssub|<PONCT-COORD>': 562,
#  'Ssub|<PONCT-CS>': 563,
#  'Ssub|<PONCT-NP>': 564,
#  'Ssub|<PONCT-PONCT>': 565,
#  'Ssub|<PONCT-PP>': 566,
#  'Ssub|<PONCT-Sint>': 567,
#  'Ssub|<PONCT-Ssub>': 568,
#  'Ssub|<PONCT-VN>': 569,
#  'Ssub|<PONCT-VPinf>': 570,
#  'Ssub|<PONCT-VPpart>': 571,
#  'Ssub|<PP-ADV>': 572,
#  'Ssub|<PP-AdP>': 573,
#  'Ssub|<PP-COORD>': 574,
#  'Ssub|<PP-NP>': 575,
#  'Ssub|<PP-PONCT>': 576,
#  'Ssub|<PP-PP>': 577,
#  'Ssub|<PP-Ssub>': 578,
#  'Ssub|<PP-VN>': 579,
#  'Ssub|<PP-VPinf>': 580,
#  'Ssub|<Sint-PONCT>': 581,
#  'Ssub|<Ssub-PONCT>': 582,
#  'Ssub|<Ssub-PP>': 583,
#  'Ssub|<VN-ADV>': 584,
#  'Ssub|<VN-AP>': 585,
#  'Ssub|<VN-AdP>': 586,
#  'Ssub|<VN-COORD>': 587,
#  'Ssub|<VN-NP>': 588,
#  'Ssub|<VN-PONCT>': 589,
#  'Ssub|<VN-PP>': 590,
#  'Ssub|<VN-Ssub>': 591,
#  'Ssub|<VN-VPinf>': 592,
#  'Ssub|<VN-VPpart>': 593,
#  'Ssub|<VPinf-AdP>': 594,
#  'Ssub|<VPinf-COORD>': 595,
#  'Ssub|<VPinf-NP>': 596,
#  'Ssub|<VPinf-PONCT>': 597,
#  'Ssub|<VPinf-PP>': 598,
#  'Ssub|<VPinf-Ssub>': 599,
#  'Ssub|<VPinf-VPinf>': 600,
#  'Ssub|<VPpart-PONCT>': 601,
#  'VN': 602,
#  'VN|<ADV-ADV>': 603,
#  'VN|<ADV-CLO>': 604,
#  'VN|<ADV-CLR>': 605,
#  'VN|<ADV-V>': 606,
#  'VN|<ADV-VINF>': 607,
#  'VN|<ADV-VPP>': 608,
#  'VN|<ADV-VS>': 609,
#  'VN|<AdP-VPP>': 610,
#  'VN|<CLO-CLO>': 611,
#  'VN|<CLO-V>': 612,
#  'VN|<CLO-VINF>': 613,
#  'VN|<CLO-VPR>': 614,
#  'VN|<CLO-VS>': 615,
#  'VN|<CLR-CLO>': 616,
#  'VN|<CLR-V>': 617,
#  'VN|<CLR-VINF>': 618,
#  'VN|<CLR-VS>': 619,
#  'VN|<CLS-ADV>': 620,
#  'VN|<CLS-V>': 621,
#  'VN|<CLS-VPP>': 622,
#  'VN|<COORD-COORD>': 623,
#  'VN|<NP-VPP>': 624,
#  'VN|<PONCT-ADV>': 625,
#  'VN|<PONCT-AdP>': 626,
#  'VN|<PONCT-PP>': 627,
#  'VN|<PONCT-VPP>': 628,
#  'VN|<PP-ADV>': 629,
#  'VN|<PP-PONCT>': 630,
#  'VN|<PP-VPP>': 631,
#  'VN|<Sint-PONCT>': 632,
#  'VN|<V-ADV>': 633,
#  'VN|<V-AdP>': 634,
#  'VN|<V-CLR>': 635,
#  'VN|<V-CLS>': 636,
#  'VN|<V-COORD>': 637,
#  'VN|<V-NP>': 638,
#  'VN|<V-Sint>': 639,
#  'VN|<V-VINF>': 640,
#  'VN|<V-VPP>': 641,
#  'VN|<VINF-ADV>': 642,
#  'VN|<VINF-PONCT>': 643,
#  'VN|<VINF-VINF>': 644,
#  'VN|<VINF-VPP>': 645,
#  'VN|<VPP-ADV>': 646,
#  'VN|<VPP-AdP>': 647,
#  'VN|<VPP-COORD>': 648,
#  'VN|<VPP-NP>': 649,
#  'VN|<VPP-VINF>': 650,
#  'VN|<VPP-VPP>': 651,
#  'VN|<VPR-ADV>': 652,
#  'VN|<VPR-PONCT>': 653,
#  'VN|<VPR-VPP>': 654,
#  'VN|<VS-ADV>': 655,
#  'VN|<VS-VPP>': 656,
#  'VPinf': 657,
#  'VPinf+VN': 658,
#  'VPinf|<ADV-COORD>': 659,
#  'VPinf|<ADV-NP>': 660,
#  'VPinf|<ADV-PONCT>': 661,
#  'VPinf|<ADV-PP>': 662,
#  'VPinf|<ADV-Ssub>': 663,
#  'VPinf|<ADV-VN>': 664,
#  'VPinf|<ADV-VPinf>': 665,
#  'VPinf|<AP-COORD>': 666,
#  'VPinf|<AP-NP>': 667,
#  'VPinf|<AP-PONCT>': 668,
#  'VPinf|<AP-PP>': 669,
#  'VPinf|<AP-Ssub>': 670,
#  'VPinf|<AdP-NP>': 671,
#  'VPinf|<AdP-PONCT>': 672,
#  'VPinf|<AdP-PP>': 673,
#  'VPinf|<COORD-COORD>': 674,
#  'VPinf|<COORD-NP>': 675,
#  'VPinf|<COORD-PONCT>': 676,
#  'VPinf|<COORD-PP>': 677,
#  'VPinf|<NP-ADV>': 678,
#  'VPinf|<NP-AdP>': 679,
#  'VPinf|<NP-COORD>': 680,
#  'VPinf|<NP-NP>': 681,
#  'VPinf|<NP-PONCT>': 682,
#  'VPinf|<NP-PP>': 683,
#  'VPinf|<NP-Ssub>': 684,
#  'VPinf|<NP-VPinf>': 685,
#  'VPinf|<P-VN>': 686,
#  'VPinf|<PONCT-ADV>': 687,
#  'VPinf|<PONCT-AP>': 688,
#  'VPinf|<PONCT-COORD>': 689,
#  'VPinf|<PONCT-NP>': 690,
#  'VPinf|<PONCT-PONCT>': 691,
#  'VPinf|<PONCT-PP>': 692,
#  'VPinf|<PONCT-Sint>': 693,
#  'VPinf|<PONCT-Ssub>': 694,
#  'VPinf|<PONCT-VN>': 695,
#  'VPinf|<PONCT-VPinf>': 696,
#  'VPinf|<PONCT-VPpart>': 697,
#  'VPinf|<PP-AdP>': 698,
#  'VPinf|<PP-COORD>': 699,
#  'VPinf|<PP-NP>': 700,
#  'VPinf|<PP-PONCT>': 701,
#  'VPinf|<PP-PP>': 702,
#  'VPinf|<PP-Ssub>': 703,
#  'VPinf|<PP-VPinf>': 704,
#  'VPinf|<Sint-PP>': 705,
#  'VPinf|<Ssub-PONCT>': 706,
#  'VPinf|<Ssub-VPinf>': 707,
#  'VPinf|<VN-ADV>': 708,
#  'VPinf|<VN-AP>': 709,
#  'VPinf|<VN-AdP>': 710,
#  'VPinf|<VN-COORD>': 711,
#  'VPinf|<VN-NP>': 712,
#  'VPinf|<VN-PONCT>': 713,
#  'VPinf|<VN-PP>': 714,
#  'VPinf|<VN-Ssub>': 715,
#  'VPinf|<VN-VPinf>': 716,
#  'VPinf|<VPinf-COORD>': 717,
#  'VPinf|<VPinf-PONCT>': 718,
#  'VPinf|<VPpart-PONCT>': 719,
#  'VPpart': 720,
#  'VPpart+VN': 721,
#  'VPpart|<ADV-ADV>': 722,
#  'VPpart|<ADV-NP>': 723,
#  'VPpart|<ADV-PONCT>': 724,
#  'VPpart|<ADV-PP>': 725,
#  'VPpart|<ADV-VPinf>': 726,
#  'VPpart|<AP-PP>': 727,
#  'VPpart|<AdP-NP>': 728,
#  'VPpart|<COORD-COORD>': 729,
#  'VPpart|<COORD-NP>': 730,
#  'VPpart|<COORD-PONCT>': 731,
#  'VPpart|<COORD-PP>': 732,
#  'VPpart|<NP-COORD>': 733,
#  'VPpart|<NP-NP>': 734,
#  'VPpart|<NP-PONCT>': 735,
#  'VPpart|<NP-PP>': 736,
#  'VPpart|<NP-VPP>': 737,
#  'VPpart|<NP-VPinf>': 738,
#  'VPpart|<PONCT-ADV>': 739,
#  'VPpart|<PONCT-COORD>': 740,
#  'VPpart|<PONCT-NP>': 741,
#  'VPpart|<PONCT-PONCT>': 742,
#  'VPpart|<PONCT-PP>': 743,
#  'VPpart|<PONCT-Sint>': 744,
#  'VPpart|<PONCT-Srel>': 745,
#  'VPpart|<PONCT-Ssub>': 746,
#  'VPpart|<PONCT-VPP>': 747,
#  'VPpart|<PONCT-VPpart>': 748,
#  'VPpart|<PP-ADV>': 749,
#  'VPpart|<PP-COORD>': 750,
#  'VPpart|<PP-NP>': 751,
#  'VPpart|<PP-PONCT>': 752,
#  'VPpart|<PP-PP>': 753,
#  'VPpart|<PP-Ssub>': 754,
#  'VPpart|<PP-VPinf>': 755,
#  'VPpart|<PP-VPpart>': 756,
#  'VPpart|<Ssub-PONCT>': 757,
#  'VPpart|<VN-ADV>': 758,
#  'VPpart|<VN-COORD>': 759,
#  'VPpart|<VN-NP>': 760,
#  'VPpart|<VN-PP>': 761,
#  'VPpart|<VN-Ssub>': 762,
#  'VPpart|<VN-VPinf>': 763,
#  'VPpart|<VPP-ADV>': 764,
#  'VPpart|<VPP-COORD>': 765,
#  'VPpart|<VPP-NP>': 766,
#  'VPpart|<VPP-PONCT>': 767,
#  'VPpart|<VPP-PP>': 768,
#  'VPpart|<VPP-VPinf>': 769,
#  'VPpart|<VPinf-PP>': 770,
#  'VPpart|<VPpart-PONCT>': 771}

# %%
#### Creating some dictionaries to optimize CYK
unaries_target = set([target for target in dict_target_non_terminals.keys() if np.ndim(target)==0])
binaries_target = set(dict_target_non_terminals.keys()) - set(unaries_target)

Grammar_unaries, Grammar_unaries_POS = defaultdict(set), defaultdict(set)
Grammar_binaries = defaultdict(set)
for nt,target in Grammar.items():
    unaries_tg = target & unaries_target
    unaries_tg_POS = unaries_tg & set(dict_POS_tags)
    binaries_tg = target & binaries_target
    if unaries_tg:
        Grammar_unaries.update({nt:unaries_tg})
        if unaries_tg_POS:
            Grammar_unaries_POS.update({nt:unaries_tg_POS})
    if binaries_tg:
        Grammar_binaries.update({nt:binaries_tg})

Grammar_unaries_inv, Grammar_unaries_POS_inv, Grammar_binaries_inv = defaultdict(set), defaultdict(set), defaultdict(set)

for nt,targets in Grammar_unaries.items():
    for target in targets:
        Grammar_unaries_inv[target].add(nt)
        
for nt,targets in Grammar_unaries_POS.items():
    for target in targets:
        Grammar_unaries_POS_inv[target].add(nt)
        
for nt,targets in Grammar_binaries.items():
    for target in targets:
        Grammar_binaries_inv[target].add(nt)

lexicon_grammar_inv = defaultdict(set)
for POS,words in lexicon_grammar.items():
    for word in words:
        lexicon_grammar_inv[word].add(POS)

left_binaries = set()
right_binaries = set()
for binary in Grammar_binaries_inv:
    left_binaries.add(binary[0])
    right_binaries.add(binary[1])
left_right_binaries = left_binaries.union(right_binaries)

dict_NT = dict_init_non_terminals.copy()
dict_NT.update({NT:idx+len(dict_init_non_terminals) for NT,idx in dict_POS_tags.items()})
dict_NT_inv = {idx:NT for NT,idx in dict_NT.items()}

del unaries_target, binaries_target

binaries = set(Grammar_binaries_inv)

# %%
def CYK_parser(sentence, 
               PCFG=PCFG, 
               lexicon_probabilities=lexicon_probabilities, 
               axioms=axioms,
               use_damerau=False,
               lev_candidates=2, 
               emb_candidates=2):

    proposed_sentence = OOV_module(sentence=sentence, lev_candidates=lev_candidates, emb_candidates=emb_candidates, damereau=use_damerau)
    
    sentence_tokens = sentence.split()   
    proposed_sentence_tokens = proposed_sentence.split()
    
    n = len(sentence_tokens)
    
    
    score = [[{} for i in range(n+1)] for j in range(n+1)]
    score_sets_left = [[set() for i in range(n+1)] for j in range(n+1)]
    score_sets_right = [[set() for i in range(n+1)] for j in range(n+1)]
    back = np.empty((n, n+1, len(dict_NT)), dtype=object)
    
    
    for i,word in enumerate(proposed_sentence_tokens):
        for POS in lexicon_grammar_inv[word.lower()]:
            score[i][i+1][POS] = lexicon_probabilities[dict_POS_tags[POS], dict_words[word.lower()]]
            if POS in left_binaries:
                score_sets_left[i][i+1].add(POS)
            if POS in right_binaries:
                score_sets_right[i][i+1].add(POS)
                      
    for span in range(2,n+1):
        for begin in range(n-span+1):
            end = begin + span
            for split in range(begin+1, end):
                container_B = score_sets_left[begin][split]
                container_C = score_sets_right[split][end]
                for B,C in binaries & set(itertools.product(container_B,container_C)):
                    for A in Grammar_binaries_inv[(B,C)]:
                        prob = score[begin][split][B] * score[split][end][C] * PCFG[dict_init_non_terminals[A],dict_target_non_terminals[(B,C)]]
                        if prob > score[begin][end].get(A,0):
                            score[begin][end][A] = prob
                            if A in left_binaries:
                                score_sets_left[begin][end].add(A)
                            if A in right_binaries:
                                score_sets_right[begin][end].add(A)
                            back[begin,end,dict_NT[A]] = (split,B,C)
            

    
    def tree(root, children):
        L = [root]
        L.extend(children)
        return str(L).replace(",","").replace("[","(").replace("]",")").replace("'","")
    
    def process_word(word, word2parse=True):
        from_= [",", "(" , ")", "[", "]", "'"]
        to_ = ["$v$i$r$g", "$l$p$", "$r$p$", "$l$b$", "$r$b$", "$a$p$"]
        
        if word2parse:
            for i,j in zip(from_,to_):
                word = word.replace(i,j)
        else:
            for i,j in zip(to_,from_):
                word = word.replace(i,j)
        
        return word
    
    def expand_node(idx_tuple, sentence_tokens):
            back_tuple = back[idx_tuple]

            if isinstance(back_tuple, tuple):
                split, B, C = back_tuple    
                idx_tuple_1, idx_tuple_2 = (idx_tuple[0], split, dict_NT[B]), (split, idx_tuple[1], dict_NT[C])
                return [tree(B,expand_node(idx_tuple_1, sentence_tokens)), tree(C,expand_node(idx_tuple_2, sentence_tokens))]  

            elif back_tuple==None:
                return [process_word(sentence_tokens.pop(0))]

            else :
                final_tuple = idx_tuple[0],idx_tuple[1], dict_NT[back_tuple]
                return [tree(back_tuple,expand_node(final_tuple, sentence_tokens))]

    def buildTree(back, sentence_tokens):

        n = back.shape[0]
        axiom_scores = np.array([score[0][n].get(ax,0) for ax in axioms])
        axiom = axioms[np.argmax(axiom_scores)]
        
        if np.all(axiom_scores==0) :
            children = [tree("NOT_IN_GRAMMAR", [process_word(word, word2parse=True)]) for word in sentence_tokens]
            return process_word(tree("", [tree("NOT_IN_GRAMMAR", children)]), word2parse=False)
        
        if n==1:
            return process_word(tree("",[tree(axiom, [process_word(sentence_tokens[0])])]), word2parse=False)
        
        idx_tuple=(0,n,dict_NT[axiom])
        mytree = process_word(tree("", [tree(axiom, expand_node(idx_tuple, sentence_tokens))]), word2parse=False)
        return mytree
    
    parse_chomsky = buildTree(back, sentence_tokens)
    
    parse_unchomsky = transform_parse(parse_chomsky, to_chomsky=False)

    return parse_unchomsky

# %%
lexicon_grammar_inv
# Out:
# defaultdict(set,
#             {'46': {'ADJ'},
#              'offensif': {'ADJ', 'AP+ADJ'},
#              'telles': {'ADJ', 'AP+ADJ'},
#              'rigoureuses': {'ADJ'},
#              'inflammatoires': {'ADJ'},
#              'embryonnaire': {'ADJ'},
#              'lépirudine': {'ADJ', 'NP+NC'},
#              'simples': {'ADJ'},
#              '3': {'ADJ', 'AP+ADJ', 'DET', 'NC', 'NP+NC'},
#              'autres': {'ADJ', 'NP+PRO', 'SENT+AP+ADJ'},
#              'ridicule': {'ADJ'},
#              'blanc': {'ADJ', 'AP+ADJ'},
#              'meilleure': {'ADJ'},
#              'apte': {'ADJ'},
#              'cinquantième': {'ADJ'},
#              'compétente': {'ADJ'},
#              'approprié': {'ADJ', 'AP+ADJ'},
#              'dévolu': {'ADJ'},
#              'judicieux': {'ADJ'},
#              '6': {'ADJ', 'AP+ADJ', 'DET', 'NP+NC'},
#              'âgé': {'ADJ'},
#              'tous': {'ADJ', 'AP+ADJ', 'DET', 'NP+PRO', 'PRO'},
#              'prochaines': {'ADJ'},
#              'inférieure': {'ADJ'},
#              'profond': {'ADJ'},
#              'nécessaire': {'ADJ', 'AP+ADJ'},
#              'issu': {'ADJ'},
#              'jaune': {'ADJ'},
#              'précédentes': {'ADJ', 'AP+ADJ'},
#              'ostéoporotiques': {'ADJ'},
#              'ancien': {'ADJ', 'AP+ADJ', 'NC'},
#              'courte': {'ADJ', 'AP+ADJ'},
#              'suffisante': {'ADJ', 'AP+ADJ'},
#              'tendre': {'ADJ'},
#              '72': {'ADJ', 'DET'},
#              '800_000': {'ADJ'},
#              'bio': {'ADJ'},
#              'agressif': {'ADJ'},
#              'cutanés': {'ADJ'},
#              'moindre': {'ADJ'},
#              'fragile': {'ADJ'},
#              'essentielle': {'ADJ', 'AP+ADJ'},
#              'curieux': {'ADJ'},
#              'utile': {'ADJ', 'AP+ADJ'},
#              'prétendu': {'ADJ'},
#              'désireuse': {'ADJ'},
#              'politiques': {'ADJ', 'AP+ADJ', 'NC'},
#              '3e': {'ADJ', 'NP+ADJ'},
#              'meilleurs': {'ADJ'},
#              'afférentes': {'ADJ'},
#              '10': {'ADJ', 'DET', 'NP+PRO'},
#              'dérivée': {'ADJ'},
#              'grosse': {'ADJ'},
#              'prochaine': {'ADJ', 'AP+ADJ'},
#              'fausses': {'ADJ'},
#              'nouvelle': {'ADJ', 'NC'},
#              'célèbre': {'ADJ'},
#              'importantes': {'ADJ', 'AP+ADJ'},
#              'naturelle': {'ADJ'},
#              '2': {'ADJ', 'AP+ADJ', 'DET', 'NC', 'NP+NC'},
#              'privilégiés': {'ADJ'},
#              'vingt': {'ADJ', 'DET'},
#              'excellente': {'ADJ'},
#              'ludique': {'ADJ'},
#              '18': {'ADJ', 'DET', 'NC'},
#              'grippaux': {'ADJ'},
#              'digne': {'ADJ'},
#              'longues': {'ADJ'},
#              'difficile': {'ADJ', 'AP+ADJ'},
#              'scientifiques': {'ADJ'},
#              'biologiques': {'ADJ', 'AP+ADJ'},
#              'belle': {'ADJ'},
#              'spectaculaire': {'ADJ', 'AP+ADJ'},
#              'publics': {'ADJ', 'AP+ADJ'},
#              'osseuse': {'ADJ', 'AP+ADJ'},
#              'fameuse': {'ADJ'},
#              'opposées': {'ADJ'},
#              'relatifs': {'ADJ'},
#              'mêmes': {'ADJ'},
#              '90': {'ADJ', 'NC'},
#              'vingts': {'ADJ'},
#              'futurs': {'ADJ'},
#              '19': {'ADJ', 'DET'},
#              'fréquentes': {'ADJ'},
#              '11': {'ADJ', 'AP+ADJ', 'DET'},
#              'habituelle': {'ADJ', 'AP+ADJ'},
#              'sévères': {'ADJ', 'AP+ADJ'},
#              'dernier': {'ADJ', 'AP+ADJ'},
#              'logique': {'ADJ', 'AP+ADJ'},
#              'bonne': {'ADJ'},
#              'indépendante': {'ADJ'},
#              'mitigé': {'ADJ'},
#              'particulier': {'ADJ', 'AP+ADJ'},
#              'rare': {'ADJ'},
#              'censé': {'ADJ'},
#              'prête': {'ADJ', 'V'},
#              '1.100': {'ADJ'},
#              'relatif': {'ADJ'},
#              'vénérables': {'ADJ', 'NC'},
#              'homéostasique': {'ADJ'},
#              'inaliénable': {'ADJ'},
#              'chauds': {'ADJ', 'AP+ADJ'},
#              'petite': {'ADJ'},
#              'terroriste': {'ADJ', 'NC'},
#              'faciles': {'ADJ'},
#              '9': {'ADJ', 'AP+ADJ', 'DET'},
#              'terminale': {'ADJ', 'AP+ADJ'},
#              'dépendante': {'ADJ'},
#              '4.3': {'ADJ', 'AP+ADJ'},
#              'brefs': {'ADJ'},
#              'régionale': {'ADJ', 'AP+ADJ'},
#              '21': {'ADJ', 'DET'},
#              'radiologique': {'ADJ'},
#              'mauvais': {'ADJ'},
#              '21e': {'ADJ'},
#              'bienvenu': {'ADJ'},
#              'fréquents': {'ADJ', 'AP+ADJ'},
#              'significative': {'ADJ', 'AP+ADJ'},
#              'faux': {'ADJ', 'NC'},
#              'nouvel': {'ADJ'},
#              'ostéoporosique': {'ADJ'},
#              'anticléricale': {'ADJ'},
#              'large': {'ADJ', 'AP+ADJ'},
#              'piètre': {'ADJ'},
#              'ultime': {'ADJ'},
#              'pénible': {'ADJ'},
#              'économiques': {'ADJ', 'AP+ADJ'},
#              'inférieur': {'ADJ', 'AP+ADJ'},
#              'supérieurs': {'ADJ', 'AP+ADJ', 'NC'},
#              '4.5': {'ADJ', 'AP+ADJ'},
#              'flagrant': {'ADJ'},
#              'proches': {'ADJ', 'NC'},
#              'déductibles': {'ADJ'},
#              'commode': {'ADJ'},
#              'premiers': {'ADJ'},
#              'primaires': {'ADJ', 'AP+ADJ'},
#              '2ème': {'ADJ'},
#              'inhumaine': {'ADJ'},
#              'financières': {'ADJ', 'AP+ADJ'},
#              'seconde': {'ADJ'},
#              'insignifiante': {'ADJ'},
#              'conforme': {'ADJ'},
#              'intestinaux': {'ADJ'},
#              'suivants': {'ADJ', 'AP+ADJ'},
#              'national': {'ADJ', 'AP+ADJ'},
#              'alimentaire': {'ADJ', 'AP+ADJ'},
#              'relative': {'ADJ', 'AP+ADJ'},
#              'mauvaise': {'ADJ'},
#              'clair': {'ADJ', 'AP+ADJ'},
#              'même': {'ADJ', 'ADV', 'AP+ADJ'},
#              'grave': {'ADJ', 'AP+ADJ'},
#              'urgente': {'ADJ', 'AP+ADJ'},
#              'brutal': {'ADJ'},
#              'éventuel': {'ADJ'},
#              'favorable': {'ADJ', 'AP+ADJ'},
#              'touchée': {'ADJ'},
#              'faibles': {'ADJ'},
#              'transparent': {'ADJ'},
#              'minces': {'ADJ'},
#              'natif': {'ADJ'},
#              'mutagène': {'ADJ'},
#              'actuelle': {'ADJ', 'AP+ADJ'},
#              'égaux': {'ADJ'},
#              'parfaite': {'ADJ'},
#              'sincères': {'ADJ'},
#              'cliniques': {'ADJ', 'AP+ADJ'},
#              '30': {'ADJ', 'AP+ADJ', 'DET'},
#              'malheureuses': {'ADJ'},
#              'remarquable': {'ADJ', 'AP+ADJ'},
#              '4.4': {'ADJ', 'AP+ADJ'},
#              'jeunes': {'ADJ', 'NC', 'NP+NC'},
#              '31': {'ADJ'},
#              'différentes': {'ADJ', 'DET'},
#              'modeste': {'ADJ'},
#              'stricts': {'ADJ'},
#              'majeure': {'ADJ', 'AP+ADJ'},
#              'éligibles': {'ADJ'},
#              'petits': {'ADJ', 'NP+NC'},
#              'prudent': {'ADJ', 'AP+ADJ'},
#              '24': {'ADJ', 'DET'},
#              'nouveaux': {'ADJ'},
#              'richissime': {'ADJ'},
#              'intestinal': {'ADJ'},
#              'postérieur': {'ADJ'},
#              'dû': {'ADJ', 'VPP'},
#              'vieux': {'ADJ'},
#              'susceptibles': {'ADJ'},
#              'respiratoires': {'ADJ', 'AP+ADJ'},
#              'anciennes': {'ADJ'},
#              'légère': {'ADJ'},
#              'synonymes': {'ADJ'},
#              'troisième': {'ADJ'},
#              'comprise': {'ADJ', 'VPP'},
#              'réglementaire': {'ADJ'},
#              'spécialisé': {'ADJ'},
#              'perchée': {'ADJ'},
#              'prêt': {'ADJ', 'NC'},
#              'responsables': {'ADJ', 'NC', 'NP+NC'},
#              'énorme': {'ADJ', 'AP+ADJ'},
#              'intéressant': {'ADJ', 'AP+ADJ'},
#              'libre': {'ADJ', 'AP+ADJ'},
#              'seul': {'ADJ', 'AP+ADJ'},
#              'municipales': {'ADJ', 'AP+ADJ', 'NC'},
#              'adaptée': {'ADJ', 'VPP', 'VPpart+VPP'},
#              'petites': {'ADJ'},
#              'derniers': {'ADJ'},
#              'soluble': {'ADJ'},
#              'grandes': {'ADJ'},
#              'mesurable': {'ADJ'},
#              '35e': {'ADJ'},
#              'incompétent': {'ADJ'},
#              'us': {'ADJ'},
#              'éloignés': {'ADJ'},
#              'classique': {'ADJ'},
#              'sure': {'ADJ'},
#              'faible': {'ADJ'},
#              '16': {'ADJ', 'DET'},
#              '16e': {'ADJ'},
#              'universitaires': {'ADJ'},
#              'blanche': {'ADJ', 'AP+ADJ', 'NPP'},
#              'originaires': {'ADJ'},
#              '12': {'ADJ', 'DET', 'NC'},
#              'agréable': {'ADJ'},
#              'chère': {'ADJ'},
#              'désireux': {'ADJ'},
#              'relatives': {'ADJ'},
#              'résistant': {'ADJ'},
#              'grand': {'ADJ', 'NPP'},
#              'actuel': {'ADJ', 'AP+ADJ'},
#              'importants': {'ADJ', 'AP+ADJ'},
#              'connexe': {'ADJ'},
#              'récente': {'ADJ', 'AP+ADJ'},
#              'politique': {'ADJ', 'AP+ADJ', 'NC', 'NP+NC'},
#              'flexible': {'ADJ'},
#              'deuxième': {'ADJ'},
#              'second': {'ADJ'},
#              'étrangères': {'ADJ', 'AP+ADJ'},
#              'vif': {'ADJ'},
#              'arbitraire': {'ADJ'},
#              '13': {'ADJ', 'DET', 'NC'},
#              'cinquante': {'ADJ'},
#              'similaires': {'ADJ', 'AP+ADJ'},
#              'taïwanaise': {'ADJ', 'AP+ADJ'},
#              'détendue': {'ADJ'},
#              '25': {'ADJ', 'AP+ADJ', 'DET'},
#              'excellent': {'ADJ'},
#              'policier': {'ADJ', 'NC'},
#              'spectaculaires': {'ADJ'},
#              'victime': {'ADJ', 'NC'},
#              'long': {'ADJ', 'NP+ADJ'},
#              'réelle': {'ADJ'},
#              'légers': {'ADJ'},
#              'prêts': {'ADJ'},
#              'dernières': {'ADJ'},
#              'équilibrée': {'ADJ', 'AP+ADJ'},
#              'petit': {'ADJ'},
#              'totale': {'ADJ', 'AP+ADJ'},
#              'âgés': {'ADJ', 'AP+ADJ'},
#              'présent': {'ADJ', 'AP+ADJ'},
#              'interminable': {'ADJ'},
#              'méprisant': {'ADJ'},
#              'écossais': {'ADJ'},
#              'oral': {'ADJ'},
#              'pratiques': {'ADJ', 'NC'},
#              'dévoué': {'ADJ', 'AP+ADJ'},
#              'enceinte': {'ADJ', 'AP+ADJ', 'NC'},
#              'éventuels': {'ADJ', 'AP+ADJ'},
#              'toute': {'ADJ', 'ADV', 'DET'},
#              'nouvelles': {'ADJ', 'AP+ADJ'},
#              '1ère': {'ADJ'},
#              'divers': {'ADJ', 'DET'},
#              'telle': {'ADJ'},
#              'légales': {'ADJ'},
#              '70_000': {'ADJ'},
#              'satisfait': {'ADJ', 'VPP'},
#              'flagrants': {'ADJ'},
#              'modérée': {'ADJ', 'AP+ADJ'},
#              '1er': {'ADJ'},
#              'sensibles': {'ADJ', 'AP+ADJ'},
#              'tels': {'ADJ'},
#              'amiable': {'ADJ'},
#              'sanguine': {'ADJ', 'AP+ADJ'},
#              'vertébrales': {'ADJ', 'AP+ADJ'},
#              'éventuelles': {'ADJ'},
#              'fanatiques': {'ADJ'},
#              'allergique': {'ADJ', 'AP+ADJ'},
#              'élevé': {'ADJ', 'AP+ADJ'},
#              'haut': {'ADJ'},
#              'indépendantes': {'ADJ'},
#              'pulmonaire': {'ADJ'},
#              'v': {'ADJ'},
#              'passionnés': {'ADJ', 'NC'},
#              'intéressée': {'ADJ', 'VPP'},
#              'défunte': {'ADJ'},
#              'symptomatique': {'ADJ', 'AP+ADJ'},
#              '5.3': {'ADJ', 'AP+ADJ'},
#              'adéquate': {'ADJ', 'AP+ADJ'},
#              'futur': {'ADJ'},
#              'sûrs': {'ADJ'},
#              'âgées': {'ADJ', 'AP+ADJ'},
#              '23': {'ADJ', 'DET', 'NP+PRO'},
#              'bas': {'ADJ', 'NC'},
#              'correspondants': {'ADJ'},
#              'indispensable': {'ADJ', 'AP+ADJ'},
#              'élevées': {'ADJ'},
#              'allergiques': {'ADJ', 'AP+ADJ'},
#              'quatre': {'ADJ', 'DET'},
#              'issue': {'ADJ', 'NC'},
#              'limpide': {'ADJ'},
#              'iiième': {'ADJ'},
#              'aggrégants': {'ADJ'},
#              '4.8': {'ADJ', 'AP+ADJ'},
#              'complète': {'ADJ', 'AP+ADJ'},
#              'asymétrique': {'ADJ'},
#              'nuisibles': {'ADJ'},
#              'véritable': {'ADJ'},
#              'sceptique': {'ADJ'},
#              'probable': {'ADJ', 'AP+ADJ'},
#              'réaliste': {'ADJ', 'AP+ADJ'},
#              '5,5': {'ADJ', 'DET'},
#              'expérimenté': {'ADJ'},
#              'normale': {'ADJ', 'AP+ADJ', 'NC'},
#              'vertébrale': {'ADJ', 'AP+ADJ'},
#              'garnis': {'ADJ'},
#              'incontournable': {'ADJ', 'AP+ADJ'},
#              'nécessaires': {'ADJ', 'AP+ADJ'},
#              '8e': {'ADJ'},
#              'simple': {'ADJ'},
#              'xxe': {'ADJ', 'NP+ADJ'},
#              'issues': {'ADJ'},
#              '15': {'ADJ', 'AP+ADJ', 'DET', 'NP+NC'},
#              '60e': {'ADJ'},
#              'disponible': {'ADJ', 'AP+ADJ'},
#              'extrême': {'ADJ', 'AP+ADJ'},
#              'principal': {'ADJ', 'AP+ADJ'},
#              'ouverte': {'ADJ', 'VPP'},
#              'propres': {'ADJ'},
#              'qualitative': {'ADJ'},
#              'coupable': {'ADJ'},
#              'plein': {'ADJ'},
#              'coronaire': {'ADJ', 'AP+ADJ'},
#              '27': {'ADJ', 'DET'},
#              'dues': {'ADJ', 'VPP'},
#              'immédiate': {'ADJ', 'AP+ADJ'},
#              'supérieure': {'ADJ', 'AP+ADJ'},
#              'ambitieuse': {'ADJ'},
#              'tardive': {'ADJ'},
#              'graves': {'ADJ', 'AP+ADJ'},
#              'métropolitain': {'ADJ'},
#              'amer': {'ADJ'},
#              'fière': {'ADJ'},
#              'rapide': {'ADJ', 'AP+ADJ'},
#              'invalidantes': {'ADJ'},
#              'tout': {'ADJ', 'ADV', 'DET', 'NP+PRO'},
#              'longs': {'ADJ'},
#              'possible': {'ADJ', 'AP+ADJ', 'NP+NC'},
#              '5': {'ADJ', 'AP+ADJ', 'DET', 'NC', 'NP+NC'},
#              'spacieux': {'ADJ'},
#              'traditionnel': {'ADJ'},
#              'double': {'ADJ'},
#              '22': {'ADJ', 'DET', 'PRO'},
#              'propre': {'ADJ'},
#              '26': {'ADJ'},
#              'brave': {'ADJ'},
#              'prochains': {'ADJ'},
#              'trois': {'ADJ', 'DET', 'PRO'},
#              'originaire': {'ADJ'},
#              '14': {'ADJ', 'DET'},
#              'meilleur': {'ADJ'},
#              'désolante': {'ADJ'},
#              'anciens': {'ADJ', 'AP+ADJ', 'NP+NC'},
#              'praticable': {'ADJ'},
#              'transitoires': {'ADJ'},
#              'élevés': {'ADJ', 'AP+ADJ'},
#              'différents': {'ADJ'},
#              'basse': {'ADJ'},
#              'premiere': {'ADJ'},
#              'fréquent': {'ADJ'},
#              'ponctuelle': {'ADJ'},
#              'dernière': {'ADJ', 'AP+ADJ'},
#              'haute': {'ADJ'},
#              'incolore': {'ADJ', 'AP+ADJ'},
#              'passionné': {'ADJ', 'VPP'},
#              'intentionnées': {'ADJ'},
#              'civilisée': {'ADJ'},
#              'présents': {'ADJ', 'AP+ADJ'},
#              'sept': {'ADJ', 'DET'},
#              'médiatisés': {'ADJ'},
#              'prochain': {'ADJ', 'AP+ADJ'},
#              '20': {'ADJ', 'DET'},
#              'seules': {'ADJ'},
#              'autre': {'ADJ', 'NP+PRO', 'PRO', 'SENT+AP+ADJ'},
#              'souhaitable': {'ADJ'},
#              '7': {'ADJ', 'AP+ADJ', 'DET'},
#              'seule': {'ADJ', 'AP+ADJ'},
#              'hypersensible': {'ADJ', 'AP+ADJ'},
#              'générale': {'ADJ', 'AP+ADJ', 'NPP'},
#              'unique': {'ADJ', 'AP+ADJ'},
#              'rétropéritonéal': {'ADJ', 'AP+ADJ', 'SENT+AP+ADJ'},
#              '17': {'ADJ', 'DET', 'NC'},
#              'grands': {'ADJ', 'NP+ADJ'},
#              'cohérents': {'ADJ'},
#              '336e': {'ADJ'},
#              'vivifiant': {'ADJ'},
#              'bon': {'ADJ', 'AP+ADJ'},
#              'légal': {'ADJ', 'AP+ADJ'},
#              'réactionnaires': {'ADJ'},
#              'plastique': {'ADJ', 'NP+NC'},
#              'enceintes': {'ADJ'},
#              'squelettiques': {'ADJ'},
#              'efficace': {'ADJ', 'AP+ADJ'},
#              'logistiques': {'ADJ'},
#              'magnifiques': {'ADJ'},
#              'quelque': {'ADJ', 'ADV', 'DET'},
#              'secondaire': {'ADJ', 'AP+ADJ'},
#              'seuls': {'ADJ', 'AP+ADJ'},
#              'mystérieux': {'ADJ'},
#              'mérité': {'ADJ'},
#              'nationales': {'ADJ'},
#              'proche': {'ADJ', 'NC'},
#              'opposé': {'ADJ', 'NC', 'VPP'},
#              'violents': {'ADJ'},
#              'strictes': {'ADJ'},
#              'responsable': {'ADJ', 'NC'},
#              'toutes': {'ADJ', 'AP+ADJ', 'DET', 'NP+PRO'},
#              'insuffisante': {'ADJ', 'AP+ADJ'},
#              'rigide': {'ADJ'},
#              'injectable': {'ADJ', 'AP+ADJ'},
#              'brève': {'ADJ'},
#              'expérimentés': {'ADJ'},
#              'cinquième': {'ADJ', 'NP+ADJ'},
#              'dramatique': {'ADJ', 'AP+ADJ'},
#              'grande': {'ADJ'},
#              'antireligieuse': {'ADJ'},
#              'libres': {'ADJ'},
#              '32': {'ADJ', 'AP+ADJ', 'DET'},
#              'libériens': {'ADJ'},
#              '8': {'ADJ', 'AP+ADJ', 'DET', 'NP+PRO'},
#              'complexe': {'ADJ', 'AP+ADJ', 'NC'},
#              'opalescente': {'ADJ'},
#              'nombreuses': {'ADJ'},
#              'économique': {'ADJ', 'AP+ADJ'},
#              'reconnaissante': {'ADJ'},
#              'sensible': {'ADJ', 'AP+ADJ'},
#              '4': {'ADJ', 'AP+ADJ', 'DET', 'NC', 'NP+NC'},
#              'multiples': {'ADJ', 'AP+ADJ'},
#              'susceptible': {'ADJ'},
#              'gros': {'ADJ'},
#              'onéreuse': {'ADJ'},
#              'vrais': {'ADJ'},
#              'malade': {'ADJ'},
#              'précises': {'ADJ'},
#              'durs': {'ADJ'},
#              'hauts': {'ADJ', 'NC'},
#              'vieille': {'ADJ', 'AP+ADJ'},
#              'banale': {'ADJ'},
#              'rares': {'ADJ', 'AP+ADJ'},
#              'direct': {'ADJ', 'AP+ADJ'},
#              'farouche': {'ADJ'},
#              'important': {'ADJ', 'AP+ADJ'},
#              'premier': {'ADJ', 'AP+ADJ'},
#              'élues': {'ADJ', 'AP+ADJ', 'VPP'},
#              'tel': {'ADJ', 'AP+ADJ'},
#              'ancienne': {'ADJ'},
#              'américain': {'ADJ', 'AP+ADJ'},
#              'valable': {'ADJ'},
#              'nouveau': {'ADJ', 'AP+ADJ'},
#              'neuvième': {'ADJ'},
#              'grippal': {'ADJ'},
#              'quadruple': {'ADJ'},
#              'saine': {'ADJ'},
#              'probables': {'ADJ'},
#              'positifs': {'ADJ'},
#              'équivalente': {'ADJ', 'AP+ADJ'},
#              'massive': {'ADJ', 'AP+ADJ'},
#              'insuffisants': {'ADJ'},
#              'stricte': {'ADJ'},
#              '60': {'ADJ', 'DET', 'PRO'},
#              'défavorables': {'ADJ'},
#              'fortes': {'ADJ'},
#              'financière': {'ADJ', 'AP+ADJ'},
#              'similaire': {'ADJ', 'AP+ADJ'},
#              'issus': {'ADJ'},
#              'précédent': {'ADJ', 'AP+ADJ'},
#              'bons': {'ADJ', 'NC'},
#              'créative': {'ADJ'},
#              'vieilles': {'ADJ'},
#              'privé': {'ADJ'},
#              'pertinentes': {'ADJ', 'AP+ADJ'},
#              'bonnes': {'ADJ'},
#              'principaux': {'ADJ', 'AP+ADJ'},
#              'longue': {'ADJ'},
#              'xixe': {'ADJ'},
#              '4.6': {'ADJ'},
#              'chers': {'ADJ'},
#              'due': {'ADJ'},
#              'paisibles': {'ADJ', 'AP+ADJ'},
#              'précoce': {'ADJ', 'AP+ADJ'},
#              'nombreux': {'ADJ', 'AP+ADJ'},
#              'incroyable': {'ADJ'},
#              'précédents': {'ADJ'},
#              'total': {'ADJ', 'AP+ADJ'},
#              'fortunée': {'ADJ'},
#              'applicables': {'ADJ'},
#              'orale': {'ADJ', 'AP+ADJ'},
#              'inférieures': {'ADJ'},
#              'fragiles': {'ADJ'},
#              'espagnole': {'ADJ'},
#              'réduit': {'ADJ', 'AP+ADJ', 'VN+V', 'VPP'},
#              'véritables': {'ADJ'},
#              'suffisants': {'ADJ'},
#              'solennelle': {'ADJ', 'AP+ADJ'},
#              'claire': {'ADJ', 'AP+ADJ'},
#              'majeurs': {'ADJ', 'AP+ADJ'},
#              'importante': {'ADJ', 'AP+ADJ'},
#              'premières': {'ADJ', 'AP+ADJ'},
#              '29': {'ADJ', 'PRO'},
#              'uniques': {'ADJ'},
#              'compétitif': {'ADJ', 'AP+ADJ'},
#              'élevée': {'ADJ', 'AP+ADJ'},
#              'égal': {'ADJ', 'NC'},
#              'quatrième': {'ADJ'},
#              'xxie': {'ADJ'},
#              'utiles': {'ADJ'},
#              'certain': {'ADJ'},
#              'fermée': {'ADJ'},
#              'abondante': {'ADJ'},
#              'supérieur': {'ADJ', 'AP+ADJ', 'NC'},
#              'volumineux': {'ADJ'},
#              'triste': {'ADJ', 'AP+ADJ'},
#              'nationaliste': {'ADJ', 'AP+ADJ', 'NC'},
#              'extrémistes': {'ADJ'},
#              'présente': {'ADJ', 'AP+ADJ', 'V', 'VN+V'},
#              'favorables': {'ADJ'},
#              'réputé': {'ADJ'},
#              '28': {'ADJ', 'DET'},
#              'aberrante': {'ADJ'},
#              'vaste': {'ADJ'},
#              '4.2': {'ADJ', 'AP+ADJ', 'NP+NC'},
#              '5.1': {'ADJ', 'AP+ADJ'},
#              'juste': {'ADJ', 'ADV'},
#              'connus': {'ADJ', 'VPP'},
#              'distincte': {'ADJ'},
#              'imputables': {'ADJ'},
#              'noble': {'ADJ'},
#              'quatorze': {'ADJ', 'DET', 'NP+ADJ'},
#              'républicaines': {'ADJ', 'AP+ADJ'},
#              'rude': {'ADJ'},
#              'deux': {'ADJ', 'DET', 'NP+PRO', 'PRO'},
#              'valide': {'ADJ'},
#              'xiie': {'ADJ'},
#              'répondeurs': {'ADJ', 'AP+ADJ'},
#              'cher': {'ADJ'},
#              'bruyants': {'ADJ'},
#              'éthiopiens': {'ADJ'},
#              'quelques': {'ADJ', 'DET'},
#              'première': {'ADJ', 'AP+ADJ', 'NC'},
#              'photographique': {'ADJ', 'AP+ADJ'},
#              'fréquente': {'ADJ', 'AP+ADJ'},
#              'précaire': {'ADJ'},
#              'justes': {'ADJ'},
#              'active': {'ADJ', 'AP+ADJ', 'NP+NC', 'VN+V'},
#              'récentes': {'ADJ'},
#              'autre-lrb-s-rrb-': {'ADJ'},
#              'ostéoporotique': {'ADJ'},
#              'inadmissible': {'ADJ'},
#              '530': {'ADJ', 'DET'},
#              'dépendants': {'ADJ'},
#              'forte': {'ADJ', 'AP+ADJ'},
#              'génital': {'ADJ'},
#              '1': {'ADJ', 'AP+ADJ', 'DET', 'NP+NC', 'PRO'},
#              'jeune': {'ADJ'},
#              '5.2': {'ADJ'},
#              'comparable': {'ADJ', 'AP+ADJ'},
#              'osseuses': {'ADJ', 'AP+ADJ'},
#              'délicieux': {'ADJ'},
#              'quel': {'ADJWH', 'AP+ADJWH', 'DET', 'DETWH', 'NP+ADJWH'},
#              'quels': {'ADJWH', 'AP+ADJWH', 'DETWH'},
#              'quelles': {'ADJWH', 'AP+ADJWH', 'DETWH'},
#              "d'_abord": {'ADV'},
#              'à_présent': {'ADV'},
#              'maintenant': {'ADV'},
#              'officiellement': {'ADV'},
#              'efficacement': {'ADV'},
#              'formellement': {'ADV'},
#              'deuxièmement': {'ADV'},
#              'constamment': {'ADV'},
#              'tant': {'ADV'},
#              'politiquement': {'ADV'},
#              'absolument': {'ADV'},
#              'impérativement': {'ADV'},
#              'douloureusement': {'ADV'},
#              'à_nouveau': {'ADV'},
#              'en_outre': {'ADV'},
#              'largement': {'ADV'},
#              'mal': {'ADV', 'NC'},
#              'partout': {'ADV'},
#              'premièrement': {'ADV'},
#              'à_la_fois': {'ADV'},
#              'troisièmement': {'ADV'},
#              'actuellement': {'ADV'},
#              'clairement': {'ADV'},
#              'correctement': {'ADV'},
#              'alors': {'ADV'},
#              'médicalement': {'ADV'},
#              'non': {'ADV', 'AP+ADV', 'NP+NC'},
#              'tout_à_fait': {'ADV'},
#              'également': {'ADV'},
#              'honnêtement': {'ADV'},
#              'vraisemblablement': {'ADV'},
#              'entre_autres': {'ADV'},
#              'indûment': {'ADV'},
#              'aucunement': {'ADV'},
#              'en_question': {'ADV'},
#              'presque': {'ADV'},
#              'au_moins': {'ADV'},
#              'pas_encore': {'ADV'},
#              'là': {'ADV'},
#              'etc.': {'ADV'},
#              'dorénavant': {'ADV'},
#              'sincèrement': {'ADV'},
#              'peu': {'ADV', 'PRO'},
#              'moins': {'ADV', 'P'},
#              'à_tout_le_moins': {'ADV'},
#              'prématurément': {'ADV'},
#              'cliniquement': {'ADV'},
#              'jamais': {'ADV'},
#              'encore': {'ADV'},
#              'explicitement': {'ADV'},
#              'essentiellement': {'ADV'},
#              'tout_de_même': {'ADV'},
#              'de_près': {'ADV'},
#              'sur_place': {'ADV'},
#              'certainement': {'ADV'},
#              'en_principe': {'ADV'},
#              'aussi': {'ADV'},
#              'frauduleusement': {'ADV'},
#              'beaucoup': {'ADV', 'PRO'},
#              'symboliquement': {'ADV'},
#              'au_total': {'ADV'},
#              "n'": {'ADV'},
#              'naturellement': {'ADV'},
#              'bientôt': {'ADV'},
#              'enfin': {'ADV'},
#              'réellement': {'ADV'},
#              "d'_ailleurs": {'ADV'},
#              'minutieusement': {'ADV'},
#              'obligatoirement': {'ADV'},
#              'délibérément': {'ADV'},
#              'plus_tard': {'ADV'},
#              'simultanément': {'ADV'},
#              'dernièrement': {'ADV'},
#              'par_ex.': {'ADV'},
#              "qu'": {'ADV', 'CS', 'NP+PROREL', 'NP+PROWH'},
#              'de_plus': {'ADV'},
#              'fort': {'ADV', 'AP+ADJ'},
#              'précisément': {'ADV'},
#              'en_cause': {'ADV'},
#              'significativement': {'ADV'},
#              'prochainement': {'ADV'},
#              'y_compris': {'ADV', 'CC', 'P'},
#              'durablement': {'ADV'},
#              'certes': {'ADV'},
#              'véritablement': {'ADV'},
#              'complétement': {'ADV'},
#              'poétiquement': {'ADV'},
#              'anonymement': {'ADV'},
#              'franchement': {'ADV'},
#              'simplement': {'ADV'},
#              'de_nouveau': {'ADV'},
#              'visiblement': {'ADV'},
#              'ne_pas': {'ADV'},
#              'dès_lors': {'ADV'},
#              'favorablement': {'ADV'},
#              'cependant': {'ADV'},
#              'peut-être': {'ADV'},
#              'de_plus_en_plus': {'ADV'},
#              'gravement': {'ADV'},
#              'plus': {'ADV', 'P'},
#              'en_partie': {'ADV'},
#              'donc': {'ADV'},
#              'après': {'ADV', 'P', 'PP+P'},
#              'loin': {'ADV'},
#              '-là': {'ADV'},
#              'en_moyenne': {'ADV'},
#              'mieux': {'ADV', 'NC'},
#              'effectivement': {'ADV'},
#              'pleinement': {'ADV'},
#              'au_fur_et_à_mesure': {'ADV'},
#              'conformément': {'ADV'},
#              'strictement': {'ADV'},
#              'sérieusement': {'ADV'},
#              'fortement': {'ADV'},
#              'du_moins': {'ADV'},
#              'hier': {'ADV'},
#              'petit_à_petit': {'ADV'},
#              'de_ce_fait': {'ADV'},
#              'à_long_terme': {'ADV'},
#              'en_effet': {'ADV'},
#              'bien_sûr': {'ADV'},
#              'suffisamment': {'ADV'},
#              "pour_l'_instant": {'ADV'},
#              'nouvellement': {'ADV'},
#              'à_priori': {'ADV'},
#              'comparativement': {'ADV'},
#              'exceptionnellement': {'ADV'},
#              'publiquement': {'ADV'},
#              'tôt': {'ADV'},
#              'non_plus': {'ADV'},
#              "tout_à_l'_heure": {'ADV'},
#              'activement': {'ADV'},
#              'par_conséquent': {'ADV'},
#              'concrètement': {'ADV'},
#              'désormais': {'ADV'},
#              'depuis_peu': {'ADV'},
#              'pour_la_première_fois': {'ADV'},
#              'quelquefois': {'ADV'},
#              'un_peu': {'ADV'},
#              'davantage': {'ADV'},
#              'inutilement': {'ADV'},
#              'en_tout': {'ADV'},
#              'paradoxalement': {'ADV'},
#              'ci-dessus': {'ADV'},
#              'aussitôt': {'ADV'},
#              'généralement': {'ADV'},
#              "aujourd'_hui": {'ADV'},
#              "tout_d'_abord": {'ADV'},
#              'initialement': {'ADV'},
#              'logiquement': {'ADV'},
#              'pour_autant': {'ADV'},
#              'manifestement': {'ADV'},
#              'consciemment': {'ADV'},
#              'tout_au_plus': {'ADV'},
#              'guère': {'ADV'},
#              'si': {'ADV', 'CS'},
#              'soudain': {'ADV'},
#              'par_exemple': {'ADV'},
#              'rapidement': {'ADV'},
#              'de_loin': {'ADV'},
#              'quatrièmement': {'ADV'},
#              'amplement': {'ADV'},
#              'attentivement': {'ADV'},
#              'courageusement': {'ADV'},
#              'il_est_vrai': {'ADV'},
#              'sans_doute': {'ADV'},
#              'en_particulier': {'ADV'},
#              'auparavant': {'ADV'},
#              'une_fois': {'ADV'},
#              'séparément': {'ADV'},
#              'relativement': {'ADV'},
#              'ainsi': {'ADV'},
#              'en_revanche': {'ADV'},
#              'en_même_temps': {'ADV'},
#              'assez': {'ADV'},
#              'psychologiquement': {'ADV'},
#              'vivement': {'ADV'},
#              'exclusivement': {'ADV'},
#              'exactement': {'ADV'},
#              'depuis': {'ADV', 'P'},
#              'fréquemment': {'ADV'},
#              'particulièrement': {'ADV'},
#              'demain': {'ADV'},
#              'par_contre': {'ADV'},
#              'de_temps_à_autre': {'ADV'},
#              'à_cet_égard': {'ADV'},
#              'pseudo-': {'ADV', 'PREF'},
#              'nettement': {'ADV'},
#              'en_place': {'ADV'},
#              'démocratiquement': {'ADV'},
#              'plutôt': {'ADV'},
#              'un_peu_plus': {'ADV'},
#              'ci-dessous': {'ADV'},
#              'par_ailleurs': {'ADV'},
#              'seulement': {'ADV'},
#              'principalement': {'ADV'},
#              'soigneusement': {'ADV'},
#              'avant_tout': {'ADV'},
#              'contre': {'ADV', 'P'},
#              'en_ce_sens': {'ADV'},
#              'en_vigueur': {'ADV'},
#              'normalement': {'ADV'},
#              'vraiment': {'ADV'},
#              'habituellement': {'ADV'},
#              'définitivement': {'ADV'},
#              'maritalement': {'ADV'},
#              'physiquement': {'ADV'},
#              'justement': {'ADV'},
#              'au-delà': {'ADV'},
#              'quotidiennement': {'ADV'},
#              'surtout': {'ADV'},
#              'à_terme': {'ADV'},
#              'parfois': {'ADV'},
#              'autant': {'ADV'},
#              'finalement': {'ADV'},
#              'a_fortiori': {'ADV'},
#              "d'_accord": {'ADV'},
#              'déjà': {'ADV'},
#              'toutefois': {'ADV'},
#              'en_plus': {'ADV'},
#              'immédiatement': {'ADV'},
#              "d'_ores_et_déjà": {'ADV'},
#              'bref': {'ADV'},
#              'rétrospectivement': {'ADV'},
#              'totalement': {'ADV'},
#              'dans_son_ensemble': {'ADV'},
#              "pour_l'_heure": {'ADV'},
#              'très': {'ADV'},
#              'progressivement': {'ADV'},
#              'notamment': {'ADV'},
#              'néanmoins': {'ADV'},
#              'ici': {'ADV'},
#              "jusqu'_à_présent": {'ADV'},
#              'extrêmement': {'ADV'},
#              'proprement': {'ADV'},
#              'probablement': {'ADV'},
#              'pourtant': {'ADV'},
#              'à_ce_sujet': {'ADV'},
#              'excessivement': {'ADV'},
#              'considérablement': {'ADV'},
#              'trop': {'ADV'},
#              'respectivement': {'ADV'},
#              'au_plus_vite': {'ADV'},
#              'près': {'ADV'},
#              'avant': {'ADV', 'AP+ADJ', 'NC', 'NP+NC', 'P'},
#              'de_même': {'ADV'},
#              'rarement': {'ADV'},
#              'autrement': {'ADV'},
#              'bonnement': {'ADV'},
#              'régulièrement': {'ADV'},
#              'approximativement': {'ADV'},
#              'malheureusement': {'ADV'},
#              'dans_ces_conditions': {'ADV'},
#              'pour_ce_faire': {'ADV'},
#              'récemment': {'ADV'},
#              'volontairement': {'ADV'},
#              'étroitement': {'ADV'},
#              'en_tout_cas': {'ADV'},
#              'là-bas': {'ADV'},
#              'spécifiquement': {'ADV'},
#              'pas': {'ADV', 'NC', 'NP+NC'},
#              'soudainement': {'ADV'},
#              'en_vain': {'ADV'},
#              'toujours': {'ADV'},
#              'illégalement': {'ADV'},
#              'brièvement': {'ADV'},
#              'non_seulement': {'ADV'},
#              'souvent': {'ADV'},
#              'lentement': {'ADV'},
#              'évidemment': {'ADV'},
#              'précédemment': {'ADV'},
#              'collectivement': {'ADV'},
#              'profondément': {'ADV'},
#              'utilement': {'ADV'},
#              'littéralement': {'ADV'},
#              'doucement': {'ADV'},
#              'que': {'ADV', 'CS', 'NP+PROREL', 'NP+PROWH', 'PROREL'},
#              'réciproquement': {'ADV'},
#              'ailleurs': {'ADV'},
#              'au_contraire': {'ADV'},
#              'fidèlement': {'ADV'},
#              'annuellement': {'ADV'},
#              'facilement': {'ADV'},
#              'parfaitement': {'ADV'},
#              "d'_une_part": {'ADV'},
#              'mystérieusement': {'ADV'},
#              'successivement': {'ADV'},
#              'quand_même': {'ADV'},
#              'en_général': {'ADV'},
#              'ne': {'ADV'},
#              'quasiment': {'ADV'},
#              'ensuite': {'ADV'},
#              'sinon': {'ADV'},
#              'en_fait': {'ADV'},
#              'complètement': {'ADV'},
#              'assurément': {'ADV'},
#              'directement': {'ADV'},
#              'plus_ou_moins': {'ADV'},
#              'conjointement': {'ADV'},
#              'longtemps': {'ADV'},
#              'bien': {'ADV'},
#              'personnellement': {'ADV'},
#              'entre_autre': {'ADV'},
#              'en_réalité': {'ADV'},
#              'à_court_terme': {'ADV'},
#              'fortuitement': {'ADV'},
#              'en_fin_de_compte': {'ADV'},
#              'bien_entendu': {'ADV'},
#              '-': {'ADV', 'CC', 'PONCT'},
#              'entre_temps': {'ADV'},
#              'secrètement': {'ADV'},
#              "c'_est_pourquoi": {'ADV'},
#              'environ': {'ADV'},
#              'jusque-là': {'ADV'},
#              'en_charge': {'ADV'},
#              'parallèlement': {'ADV'},
#              'fermement': {'ADV'},
#              'à_peu_près': {'ADV'},
#              "d'_autre_part": {'ADV'},
#              'dûment': {'ADV'},
#              'heureusement': {'ADV'},
#              'convenablement': {'ADV'},
#              'potentiellement': {'ADV'},
#              'systématiquement': {'ADV'},
#              'vite': {'ADV'},
#              'apparemment': {'ADV'},
#              'entièrement': {'ADV'},
#              'uniquement': {'ADV'},
#              'contractuellement': {'ADV'},
#              'légèrement': {'ADV'},
#              'où': {'ADVWH', 'NP+PROREL'},
#              'comment': {'ADVWH'},
#              'pourquoi': {'ADVWH'},
#              'combien': {'ADVWH'},
#              'standards': {'AP+ADJ', 'NC'},
#              'buccale': {'AP+ADJ'},
#              'transeuropéen': {'AP+ADJ'},
#              'speciale-lrb-s-rrb-': {'AP+ADJ'},
#              'étroits': {'AP+ADJ'},
#              'identiques': {'AP+ADJ'},
#              'intergouvernementale': {'AP+ADJ'},
#              'glomérulaire': {'AP+ADJ'},
#              'chirurgicale': {'AP+ADJ'},
#              'intéressantes': {'AP+ADJ'},
#              'sanguins': {'AP+ADJ'},
#              'croisées': {'AP+ADJ'},
#              'judiciaire': {'AP+ADJ'},
#              'parathyroïde': {'AP+ADJ'},
#              'standard': {'AP+ADJ'},
#              'alcalines': {'AP+ADJ'},
#              'incontrôlée': {'AP+ADJ'},
#              'supplémentaire': {'AP+ADJ'},
#              'pénale': {'AP+ADJ'},
#              'difficiles': {'AP+ADJ'},
#              'parisiens': {'AP+ADJ'},
#              'humaines': {'AP+ADJ'},
#              'allaitantes': {'AP+ADJ'},
#              'dictatorial': {'AP+ADJ'},
#              'boisé': {'AP+ADJ'},
#              'morphométriques': {'AP+ADJ'},
#              'syndicaux': {'AP+ADJ'},
#              'commerciale': {'AP+ADJ'},
#              'pluviales': {'AP+ADJ'},
#              'technologique': {'AP+ADJ'},
#              'extérieur': {'AP+ADJ'},
#              'préventifs': {'AP+ADJ'},
#              'fluorescents': {'AP+ADJ'},
#              'minérale': {'AP+ADJ'},
#              'incertaine': {'AP+ADJ'},
#              'multiple': {'AP+ADJ'},
#              'souverains': {'AP+ADJ'},
#              'limitée': {'AP+ADJ', 'VPP', 'VPpart+VPP'},
#              'civile': {'AP+ADJ'},
#              'dynamiques': {'AP+ADJ'},
#              'interne': {'AP+ADJ'},
#              'malveillant': {'AP+ADJ'},
#              'intercommunal': {'AP+ADJ'},
#              'masculin': {'AP+ADJ'},
#              'sportif': {'AP+ADJ'},
#              'correctionnel': {'AP+ADJ'},
#              'allemands': {'AP+ADJ'},
#              'étrangers': {'AP+ADJ'},
#              'républicains': {'AP+ADJ', 'NC'},
#              'légitimes': {'AP+ADJ'},
#              '161': {'AP+ADJ'},
#              'commun': {'AP+ADJ'},
#              'françaises': {'AP+ADJ'},
#              'intraveineuse': {'AP+ADJ'},
#              'individuel': {'AP+ADJ'},
#              'traditionalistes': {'AP+ADJ'},
#              'temporaires': {'AP+ADJ'},
#              'accidentelle': {'AP+ADJ'},
#              'législatives': {'AP+ADJ', 'NC'},
#              'caritatives': {'AP+ADJ'},
#              'aigu': {'AP+ADJ'},
#              'inchangée': {'AP+ADJ'},
#              'minéraux': {'AP+ADJ', 'NP+NC'},
#              'instable': {'AP+ADJ'},
#              'dreyfusardes': {'AP+ADJ'},
#              'explicites': {'AP+ADJ'},
#              'morales': {'AP+ADJ'},
#              'réel': {'AP+ADJ'},
#              'commercial': {'AP+ADJ'},
#              'urgent': {'AP+ADJ'},
#              'additionnels': {'AP+ADJ'},
#              'occultes': {'AP+ADJ'},
#              'intouchables': {'AP+ADJ'},
#              'aisée': {'AP+ADJ'},
#              'tragique': {'AP+ADJ'},
#              'électriques': {'AP+ADJ'},
#              'pétrolier': {'AP+ADJ'},
#              'départemental': {'AP+ADJ'},
#              'contrasté': {'AP+ADJ'},
#              'mélodramatique': {'AP+ADJ'},
#              'électives': {'AP+ADJ'},
#              'allemand': {'AP+ADJ'},
#              'successifs': {'AP+ADJ'},
#              'protéique': {'AP+ADJ'},
#              'républicain': {'AP+ADJ'},
#              'israélite': {'AP+ADJ'},
#              'territoriale': {'AP+ADJ'},
#              ...})

# %%
lexicon_grammar_inv = defaultdict(set)
for POS,words in lexicon_grammar.items():
    for word in words:
        lexicon_grammar_inv[word].add(POS)

# %%
lexicon
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-68bc70cdfa42> in <module>
# ----> 1 lexicon
#
# NameError: name 'lexicon' is not defined

# %%
sentence = sentences_train[3]
proposed_sentence = OOV_module(sentence=sentence, lev_candidates=lev_candidates, emb_candidates=emb_candidates, damereau=use_damereau)
sentence_tokens = sentence.split()   
proposed_sentence_tokens = proposed_sentence.split()
n = len(sentence_tokens)

# %%
proposed_sentence
# Out:
# "Ensuite , fut installée une autre forge à la Vacquerie , à l' emplacement aujourd'_hui de Cora ."

# %%
Tree.fromstring(corpus_train[3])
# Out:
# Tree('', [Tree('SENT', [Tree('ADV', ['Ensuite']), Tree('PONCT', [',']), Tree('VN', [Tree('V', ['fut']), Tree('VPP', ['installée'])]), Tree('NP', [Tree('DET', ['une']), Tree('ADJ', ['autre']), Tree('NC', ['forge'])]), Tree('PP', [Tree('P', ['à']), Tree('NP', [Tree('DET', ['la']), Tree('NPP', ['Vacquerie'])])]), Tree('PONCT', [',']), Tree('PP', [Tree('P', ['à']), Tree('NP', [Tree('DET', ["l'"]), Tree('NC', ['emplacement']), Tree('ADV', ["aujourd'_hui"]), Tree('PP', [Tree('P', ['de']), Tree('NP', [Tree('NPP', ['Cora'])])])])]), Tree('PONCT', ['.'])])])

# %%
Tree.fromstring(CYK_parser(sentences_train[3]))
# Out:
# Tree('', [Tree('SENT', [Tree('ADV', ['Ensuite']), Tree('PONCT', [',']), Tree('VN', [Tree('V', ['fut']), Tree('VPP', ['installée'])]), Tree('NP', [Tree('DET', ['une']), Tree('ADJ', ['autre']), Tree('NC', ['forge'])]), Tree('PP', [Tree('P', ['à']), Tree('NP', [Tree('DET', ['la']), Tree('NPP', ['Vacquerie'])])]), Tree('PONCT', [',']), Tree('PP', [Tree('P', ['à']), Tree('NP', [Tree('DET', ["l'"]), Tree('NC', ['emplacement']), Tree('ADV', ["aujourd'_hui"]), Tree('PP', [Tree('P', ['de']), Tree('NP', [Tree('NPP', ['Cora'])])])])]), Tree('PONCT', ['.'])])])

# %%
if argparser.written_sentence :
    print("Parsing sentence :",argparser.sent_to_parse)
    parses_results = CYK_parser(sentence = argparser.sent_to_parse)
    print(parses_results)
    
else :
    print("Parsing sentences in :",argparser.file_to_parse)
    if argparser.multiprocess:
        print("Using multiprocessing..")
        
        with io.open(argparser.file_to_parse, encoding='utf-8') as f:
            sentences = [sentence for sentence in f]
        tic = time.time()
        parses_results = multiprocess_func(CYK_parser, sentences, n_jobs=argparser.n_cpus)
        toc = time.time()
        print("Time elapsed :",(toc-tic)//60,"min",np.round((toc-tic)%60,2),"s")
        
    else :
        parses_results = []
        tic = time.time()
        with io.open(argparser.file_to_parse, encoding='utf-8') as f:
            for sentence in tqdm(f):
                parses_results.append(CYK_parser(sentence))
        toc = time.time()
        print("Time elapsed :",(toc-tic)//60,"min",np.round((toc-tic)%60,2),"s")
                
    print("\nWriting output to :",argparser.output_path)
    with open(argparser.output_path, 'w', encoding="utf-8") as f:
        for idx,parse in enumerate(parses_results):
            if idx < len(parses_results)-1:
                f.write(parse+"\n")
            else:
                f.write(parse)
    f.close()

# %%
def P_CYK(sentence,grammar):
    
    split_sentence = sentence.split()
    r = len(grammar.non_terminals) 
    n = len(split_sentence)
    P = np.zeros((n,n,r))
    back = np.empty((n,n,r),dtype=np.ndarray)

    
    for s,word in enumerate(split_sentence):
        for pos in grammar.lexicon[word]:
            v = grammar.pos2index[pos]
            P[0,s,v] = grammar.lexicon[word][pos]
    
    #browse unaries
    for s in range(n):
        for prod in grammar.pcfg._productions:
            if len(prod._rhs)==1:
                v1 = grammar.pos2index[prod._lhs]
                v2 = grammar.pos2index[prod._rhs[0]]
                prob_transition = P[0,s,v2] * prod._ProbabilisticMixIn__prob
                if P[0,s,v2]>0 and prob_transition > P[0,s,v1]: 
                    P[0,s,v1] = prob_transition
                    back[0,s,v1] = (0,v2,None)
                    
    #browse binary rules
    for l in range(2,n+1): #length of span
        for s in range(1,n-l+2): #start of span
            for p in range(0,l): #partition of span 
                for prod in grammar.pcfg._productions:
                    if len(prod._rhs)==2: #if binary rule
                        a = grammar.pos2index[prod._lhs]
                        Rb = prod._rhs[0]
                        Rc = prod._rhs[1]
                        b = grammar.pos2index[Rb]
                        c = grammar.pos2index[Rc]
                        prob_prod = prod._ProbabilisticMixIn__prob
                        
                        prob_splitting = prob_prod * P[p-1,s-1,b] * P[l-p-1,s+p-1,c]
                        if P[p-1,s-1,b] > 0 and P[l-p-1,s+p-1,c] > 0 and P[l-1,s-1,a] < prob_splitting:
                            #print(prod)
                            P[l-1,s-1,a] = prob_splitting
                            back[l-1,s-1,a] = (p,b,c)
    
    return P,back 

def build_tree(backp,sentence,grammar,length=-1,start=0,pos=0,is_splitted = False): 
    S = ''
    if not is_splitted: 
        sentence = sentence.split()
    indexes = backp[length,start,pos]
    if indexes is None: 
        return sentence[start]
    else: 
        p,b,c = indexes
        if c is None and not b is None: 
            return "(" + grammar.non_terminals[b]._symbol+ " " + sentence[start] + ")"
        #print(non_terminals[pos],non_terminals[b],non_terminals[c])
        S += "(" +grammar.non_terminals[b]._symbol+" "+ build_tree(backp,sentence,grammar,p-1,start,b,is_splitted = True) +")"
        S += "(" +grammar.non_terminals[c]._symbol+" "+ build_tree(backp,sentence,grammar,length-p,start+p,c,is_splitted = True) +")" 
            
    return S

def correct_string(string):
    return '( (SENT' + string + '))'

def un_chomsky(bracket_string):
    
    tree = nltk.tree.Tree.fromstring(correct_string(bracket_string))
    nltk.treetransforms.un_chomsky_normal_form(tree)
    result = tree.pformat().replace('\n','')
    return result
